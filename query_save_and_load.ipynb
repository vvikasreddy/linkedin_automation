# %%
import json
import psycopg2
import unicodedata
from psycopg2.extras import execute_values

# %%
# Load the JSON file
with open('lnkdn.json', 'r') as file:
    combined_records = json.load(file)

# Display the loaded data
combined_records
# Out:
# [{'message_id': 'messg_0',
#   'conversation_id': 'conv_0',
#   'platform': 'LinkedIn',
#   'connection_name': 'Namruth Thimmapuram',
#   'message_sender': 'Vikas Reddy Venkannagari',
#   'message_date': '2024-11-04 20:28:00',
#   'message_text': "Hi Namruth Goud,\n\nIt's been some time since we connected. We both studied at University of Maryland Baltimore County. How have you been?",
#   'connection_title': "Master's in Data Science @UMBC"},
#  {'message_id': 'messg_0',
#   'conversation_id': 'conv_1',
#   'platform': 'LinkedIn',
#   'connection_name': 'Namruth Thimmapuram',
#   'message_sender': 'Namruth Thimmapuram',
#   'message_date': '2024-11-10 23:25:00',
#   'message_text': 'Hi, Vikas Reddy',
#   'connection_title': "Master's in Data Science @UMBC"},
#  {'message_id': 'messg_0',
#   'conversation_id': 'conv_2',
#   'platform': 'LinkedIn',
#   'connection_name': 'Namruth Thimmapuram',
#   'message_sender': 'Namruth Thimmapuram',
#   'message_date': '2024-11-10 23:25:00',
#   'message_text': "I'm good",
#   'connection_title': "Master's in Data Science @UMBC"},
#  {'message_id': 'messg_0',
#   'conversation_id': 'conv_3',
#   'platform': 'LinkedIn',
#   'connection_name': 'Namruth Thimmapuram',
#   'message_sender': 'Namruth Thimmapuram',
#   'message_date': '2024-11-10 23:25:00',
#   'message_text': 'How about you?',
#   'connection_title': "Master's in Data Science @UMBC"},
#  {'message_id': 'messg_0',
#   'conversation_id': 'conv_4',
#   'platform': 'LinkedIn',
#   'connection_name': 'Namruth Thimmapuram',
#   'message_sender': 'Vikas Reddy Venkannagari',
#   'message_date': '2024-11-11 20:37:00',
#   'message_text': "I'm good, too",
#   'connection_title': "Master's in Data Science @UMBC"},
#  {'message_id': 'messg_0',
#   'conversation_id': 'conv_5',
#   'platform': 'LinkedIn',
#   'connection_name': 'Namruth Thimmapuram',
#   'message_sender': 'Vikas Reddy Venkannagari',
#   'message_date': '2024-11-15 22:42:00',
#   'message_text': 'profile pic bagunda ?',
#   'connection_title': "Master's in Data Science @UMBC"},
#  {'message_id': 'messg_0',
#   'conversation_id': 'conv_6',
#   'platform': 'LinkedIn',
#   'connection_name': 'Namruth Thimmapuram',
#   'message_sender': 'Vikas Reddy Venkannagari',
#   'message_date': '2024-11-15 22:56:00',
#   'message_text': 'baane extralu',
#   'connection_title': "Master's in Data Science @UMBC"},
#  {'message_id': 'messg_0',
#   'conversation_id': 'conv_7',
#   'platform': 'LinkedIn',
#   'connection_name': 'Namruth Thimmapuram',
#   'message_sender': 'Namruth Thimmapuram',
#   'message_date': '2024-11-16 08:37:00',
#   'message_text': 'Yeah',
#   'connection_title': "Master's in Data Science @UMBC"},
#  {'message_id': 'messg_0',
#   'conversation_id': 'conv_8',
#   'platform': 'LinkedIn',
#   'connection_name': 'Namruth Thimmapuram',
#   'message_sender': 'Vikas Reddy Venkannagari',
#   'message_date': '2025-01-09 19:50:00',
#   'message_text': '',
#   'connection_title': "Master's in Data Science @UMBC"},
#  {'message_id': 'messg_0',
#   'conversation_id': 'conv_9',
#   'platform': 'LinkedIn',
#   'connection_name': 'Namruth Thimmapuram',
#   'message_sender': 'Vikas Reddy Venkannagari',
#   'message_date': '2025-01-14 15:48:00',
#   'message_text': '',
#   'connection_title': "Master's in Data Science @UMBC"},
#  {'message_id': 'messg_0',
#   'conversation_id': 'conv_10',
#   'platform': 'LinkedIn',
#   'connection_name': 'Namruth Thimmapuram',
#   'message_sender': 'Vikas Reddy Venkannagari',
#   'message_date': '2025-01-14 15:49:00',
#   'message_text': '',
#   'connection_title': "Master's in Data Science @UMBC"},
#  {'message_id': 'messg_0',
#   'conversation_id': 'conv_11',
#   'platform': 'LinkedIn',
#   'connection_name': 'Namruth Thimmapuram',
#   'message_sender': 'Vikas Reddy Venkannagari',
#   'message_date': '2025-01-14 15:49:00',
#   'message_text': 'Rey, idi chaduvu, clarity vastadi',
#   'connection_title': "Master's in Data Science @UMBC"},
#  {'message_id': 'messg_0',
#   'conversation_id': 'conv_12',
#   'platform': 'LinkedIn',
#   'connection_name': 'Namruth Thimmapuram',
#   'message_sender': 'Namruth Thimmapuram',
#   'message_date': '2025-01-28 13:40:00',
#   'message_text': 'endi ra adantha',
#   'connection_title': "Master's in Data Science @UMBC"},
#  {'message_id': 'messg_0',
#   'conversation_id': 'conv_13',
#   'platform': 'LinkedIn',
#   'connection_name': 'Namruth Thimmapuram',
#   'message_sender': 'Vikas Reddy Venkannagari',
#   'message_date': '2025-05-09 19:48:00',
#   'message_text': 'Hi ',
#   'connection_title': "Master's in Data Science @UMBC"},
#  {'message_id': 'messg_0',
#   'conversation_id': 'conv_14',
#   'platform': 'LinkedIn',
#   'connection_name': 'Namruth Thimmapuram',
#   'message_sender': 'Namruth Thimmapuram',
#   'message_date': '2025-05-09 19:48:00',
#   'message_text': 'How are you?',
#   'connection_title': "Master's in Data Science @UMBC"},
#  {'message_id': 'messg_0',
#   'conversation_id': 'conv_15',
#   'platform': 'LinkedIn',
#   'connection_name': 'Namruth Thimmapuram',
#   'message_sender': 'Vikas Reddy Venkannagari',
#   'message_date': '2025-05-09 19:48:00',
#   'message_text': 'What are you doing ',
#   'connection_title': "Master's in Data Science @UMBC"},
#  {'message_id': 'messg_0',
#   'conversation_id': 'conv_16',
#   'platform': 'LinkedIn',
#   'connection_name': 'Namruth Thimmapuram',
#   'message_sender': 'Namruth Thimmapuram',
#   'message_date': '2025-05-09 19:48:00',
#   'message_text': 'Working',
#   'connection_title': "Master's in Data Science @UMBC"},
#  {'message_id': 'messg_0',
#   'conversation_id': 'conv_17',
#   'platform': 'LinkedIn',
#   'connection_name': 'Namruth Thimmapuram',
#   'message_sender': 'Namruth Thimmapuram',
#   'message_date': '2025-05-09 19:48:00',
#   'message_text': 'And you?',
#   'connection_title': "Master's in Data Science @UMBC"},
#  {'message_id': 'messg_0',
#   'conversation_id': 'conv_18',
#   'platform': 'LinkedIn',
#   'connection_name': 'Namruth Thimmapuram',
#   'message_sender': 'Vikas Reddy Venkannagari',
#   'message_date': '2025-05-09 19:48:00',
#   'message_text': "Let's gor for a walk ?",
#   'connection_title': "Master's in Data Science @UMBC"},
#  {'message_id': 'messg_0',
#   'conversation_id': 'conv_19',
#   'platform': 'LinkedIn',
#   'connection_name': 'Namruth Thimmapuram',
#   'message_sender': 'Vikas Reddy Venkannagari',
#   'message_date': '2025-05-09 19:48:00',
#   'message_text': 'Now ?',
#   'connection_title': "Master's in Data Science @UMBC"},
#  {'message_id': 'messg_0',
#   'conversation_id': 'conv_20',
#   'platform': 'LinkedIn',
#   'connection_name': 'Namruth Thimmapuram',
#   'message_sender': 'Vikas Reddy Venkannagari',
#   'message_date': '2025-05-09 19:48:00',
#   'message_text': 'Thank you',
#   'connection_title': "Master's in Data Science @UMBC"},
#  {'message_id': 'messg_0',
#   'conversation_id': 'conv_21',
#   'platform': 'LinkedIn',
#   'connection_name': 'Namruth Thimmapuram',
#   'message_sender': 'Namruth Thimmapuram',
#   'message_date': '2025-05-09 19:48:00',
#   'message_text': 'Right now',
#   'connection_title': "Master's in Data Science @UMBC"},
#  {'message_id': 'messg_0',
#   'conversation_id': 'conv_22',
#   'platform': 'LinkedIn',
#   'connection_name': 'Namruth Thimmapuram',
#   'message_sender': 'Vikas Reddy Venkannagari',
#   'message_date': '2025-05-09 19:48:00',
#   'message_text': 'Yeah',
#   'connection_title': "Master's in Data Science @UMBC"},
#  {'message_id': 'messg_0',
#   'conversation_id': 'conv_23',
#   'platform': 'LinkedIn',
#   'connection_name': 'Namruth Thimmapuram',
#   'message_sender': 'Namruth Thimmapuram',
#   'message_date': '2025-05-09 19:48:00',
#   'message_text': 'Goodbye',
#   'connection_title': "Master's in Data Science @UMBC"},
#  {'message_id': 'messg_1',
#   'conversation_id': 'conv_0',
#   'platform': 'LinkedIn',
#   'connection_name': 'Haixu Leng',
#   'message_sender': 'Vikas Reddy Venkannagari',
#   'message_date': '2025-05-09 19:36:00',
#   'message_text': 'Hey Haixu, I’m Vikas, a current grad student at UMBC, applying for Algorithm Engineer role at KLA. As a fellow UMBC alum, I’d love your take—would you be open to a referral? I bring over 1.5 years of relevant experience and am happy to share my resume. Thanks!',
#   'connection_title': 'Algorithm Engineer'},
#  {'message_id': 'messg_2',
#   'conversation_id': 'conv_0',
#   'platform': 'LinkedIn',
#   'connection_name': 'Sameer Kibey',
#   'message_sender': 'Vikas Reddy Venkannagari',
#   'message_date': '2024-04-05 23:31:00',
#   'message_text': 'Hi, \n\nI am currently enrolled in MS program (Data science) at University of Maryland, Baltimore County, and looking for summer 2024 internship opportunities, Is there any position available in your team? Can you help me out here. \n\nThanks and regards,\nVikas Reddy',
#   'connection_title': 'Software Engineering Leader | oneAPI Developer SW | Streaming Media (Video/Audio) and AI | Technical and Organizational Leadership'},
#  {'message_id': 'messg_2',
#   'conversation_id': 'conv_1',
#   'platform': 'LinkedIn',
#   'connection_name': 'Sameer Kibey',
#   'message_sender': 'Sameer Kibey',
#   'message_date': '2024-04-06 13:54:00',
#   'message_text': 'Hi Vikas, my team is not hiring at the moment. But I will keep an eye on any opportunities. Suggest you to add your resume when you contact people, and briefly mention key competencies/core skills. Thus they can see what areas you will be a good fit in. ',
#   'connection_title': 'Software Engineering Leader | oneAPI Developer SW | Streaming Media (Video/Audio) and AI | Technical and Organizational Leadership'},
#  {'message_id': 'messg_2',
#   'conversation_id': 'conv_2',
#   'platform': 'LinkedIn',
#   'connection_name': 'Sameer Kibey',
#   'message_sender': 'Vikas Reddy Venkannagari',
#   'message_date': '2024-04-06 15:25:00',
#   'message_text': 'hey sameer, \n \nI am currently volunteering at a research lab in UMBC. Where we developing a transformer based model to predict the emotions by fusing EEG signal data and facial features, targeted publishing date is less than 2 months. Coming to my interests I am interested in computer vision and nlp based tasks. I am attaching my resume for your reference.(Edited)',
#   'connection_title': 'Software Engineering Leader | oneAPI Developer SW | Streaming Media (Video/Audio) and AI | Technical and Organizational Leadership'},
#  {'message_id': 'messg_2',
#   'conversation_id': 'conv_3',
#   'platform': 'LinkedIn',
#   'connection_name': 'Sameer Kibey',
#   'message_sender': 'Vikas Reddy Venkannagari',
#   'message_date': '2024-04-09 23:54:00',
#   'message_text': 'Hey Sameer, \n \nI found an internship opportunity which I believe is a perfect fit for my background. The job is : JR026142, role of "Foundational AI Research Intern". Can you please refer me to this position. \n \nI am attaching my resume for your reference,',
#   'connection_title': 'Software Engineering Leader | oneAPI Developer SW | Streaming Media (Video/Audio) and AI | Technical and Organizational Leadership'},
#  {'message_id': 'messg_2',
#   'conversation_id': 'conv_4',
#   'platform': 'LinkedIn',
#   'connection_name': 'Sameer Kibey',
#   'message_sender': 'Sameer Kibey',
#   'message_date': '2024-06-02 17:12:00',
#   'message_text': 'Hello Vikas, I missed responding to your message. My apologies. Are you still looking for summer internship role? I can forward your resume to the hiring manager for JR026142. However, on your resume the LinkedIn link is not valid. Suggest you to correct that. Also add a tag line at the top of the resume, that helps the reader understand what kind of role you are looking for. Something like - "Experienced graduate student looking for an internship in AI/ML/Deep Learning <or add other areas here> for Summer 2024".',
#   'connection_title': 'Software Engineering Leader | oneAPI Developer SW | Streaming Media (Video/Audio) and AI | Technical and Organizational Leadership'},
#  {'message_id': 'messg_2',
#   'conversation_id': 'conv_5',
#   'platform': 'LinkedIn',
#   'connection_name': 'Sameer Kibey',
#   'message_sender': 'Vikas Reddy Venkannagari',
#   'message_date': '2024-06-02 17:12:00',
#   'message_text': 'Sure Sameer, I will make the changes.',
#   'connection_title': 'Software Engineering Leader | oneAPI Developer SW | Streaming Media (Video/Audio) and AI | Technical and Organizational Leadership'},
#  {'message_id': 'messg_2',
#   'conversation_id': 'conv_6',
#   'platform': 'LinkedIn',
#   'connection_name': 'Sameer Kibey',
#   'message_sender': 'Vikas Reddy Venkannagari',
#   'message_date': '2024-07-13 15:56:00',
#   'message_text': 'Hey Sameer, I have made suitable changes and also updated my resume with my latest projects. \n \nI believe the above position is no longer open, can you please refer to the role Multimodal AI Research Intern, Job ID JR0266069. (fall 2024 internship)\n \nI would also love some comments to improve on my resume.',
#   'connection_title': 'Software Engineering Leader | oneAPI Developer SW | Streaming Media (Video/Audio) and AI | Technical and Organizational Leadership'},
#  {'message_id': 'messg_2',
#   'conversation_id': 'conv_7',
#   'platform': 'LinkedIn',
#   'connection_name': 'Sameer Kibey',
#   'message_sender': 'Sameer Kibey',
#   'message_date': '2024-07-13 21:56:00',
#   'message_text': 'I will submit referral for the internship position.. resume looks fine to me. ',
#   'connection_title': 'Software Engineering Leader | oneAPI Developer SW | Streaming Media (Video/Audio) and AI | Technical and Organizational Leadership'},
#  {'message_id': 'messg_2',
#   'conversation_id': 'conv_8',
#   'platform': 'LinkedIn',
#   'connection_name': 'Sameer Kibey',
#   'message_sender': 'Vikas Reddy Venkannagari',
#   'message_date': '2024-07-13 21:57:00',
#   'message_text': 'Thank you very much',
#   'connection_title': 'Software Engineering Leader | oneAPI Developer SW | Streaming Media (Video/Audio) and AI | Technical and Organizational Leadership'},
#  {'message_id': 'messg_2',
#   'conversation_id': 'conv_9',
#   'platform': 'LinkedIn',
#   'connection_name': 'Sameer Kibey',
#   'message_sender': 'Sameer Kibey',
#   'message_date': '2024-07-16 20:37:00',
#   'message_text': 'I submitted the referral, but note that the position lists minimum requirement as PhD candidate. I am not sure how flexible they would be to consider MS candidates. Anyway, all the best!',
#   'connection_title': 'Software Engineering Leader | oneAPI Developer SW | Streaming Media (Video/Audio) and AI | Technical and Organizational Leadership'},
#  {'message_id': 'messg_2',
#   'conversation_id': 'conv_10',
#   'platform': 'LinkedIn',
#   'connection_name': 'Sameer Kibey',
#   'message_sender': 'Vikas Reddy Venkannagari',
#   'message_date': '2024-07-16 20:38:00',
#   'message_text': 'Yeah, and I saw there were no other fall 2024 internship opportunities',
#   'connection_title': 'Software Engineering Leader | oneAPI Developer SW | Streaming Media (Video/Audio) and AI | Technical and Organizational Leadership'},
#  {'message_id': 'messg_2',
#   'conversation_id': 'conv_11',
#   'platform': 'LinkedIn',
#   'connection_name': 'Sameer Kibey',
#   'message_sender': 'Vikas Reddy Venkannagari',
#   'message_date': '2024-07-16 20:38:00',
#   'message_text': 'Thanks again, for the referral. ',
#   'connection_title': 'Software Engineering Leader | oneAPI Developer SW | Streaming Media (Video/Audio) and AI | Technical and Organizational Leadership'},
#  {'message_id': 'messg_2',
#   'conversation_id': 'conv_12',
#   'platform': 'LinkedIn',
#   'connection_name': 'Sameer Kibey',
#   'message_sender': 'Vikas Reddy Venkannagari',
#   'message_date': '2025-04-14 10:24:00',
#   'message_text': "Hi Sameer, hope you're doing well.\nThanks again for the earlier referral.\n\nWould it be a ridiculous idea to ask if you or your team are hiring for other data/software roles?",
#   'connection_title': 'Software Engineering Leader | oneAPI Developer SW | Streaming Media (Video/Audio) and AI | Technical and Organizational Leadership'},
#  {'message_id': 'messg_2',
#   'conversation_id': 'conv_13',
#   'platform': 'LinkedIn',
#   'connection_name': 'Sameer Kibey',
#   'message_sender': 'Sameer Kibey',
#   'message_date': '2025-05-09 12:18:00',
#   'message_text': 'Hello Vikas, hiring is slow at Intel at the moment. My team is not hiring for full time roles. I can send your resume to my contacts at Nvidia and Amazon that work in AI. Send me your latest resume.',
#   'connection_title': 'Software Engineering Leader | oneAPI Developer SW | Streaming Media (Video/Audio) and AI | Technical and Organizational Leadership'},
#  {'message_id': 'messg_2',
#   'conversation_id': 'conv_14',
#   'platform': 'LinkedIn',
#   'connection_name': 'Sameer Kibey',
#   'message_sender': 'Vikas Reddy Venkannagari',
#   'message_date': '2025-05-09 12:18:00',
#   'message_text': 'Hi Sameer,\n\nThanks for your kind reply! I’m working on an exciting agentic AI project that will make a great addition to my résumé. It should be finalized this weekend, and I’ll send my resume over in 2 days.',
#   'connection_title': 'Software Engineering Leader | oneAPI Developer SW | Streaming Media (Video/Audio) and AI | Technical and Organizational Leadership'},
#  {'message_id': 'messg_2',
#   'conversation_id': 'conv_15',
#   'platform': 'LinkedIn',
#   'connection_name': 'Sameer Kibey',
#   'message_sender': 'Sameer Kibey',
#   'message_date': '2025-05-09 12:18:00',
#   'message_text': 'ok sounds good.',
#   'connection_title': 'Software Engineering Leader | oneAPI Developer SW | Streaming Media (Video/Audio) and AI | Technical and Organizational Leadership'},
#  {'message_id': 'messg_3',
#   'conversation_id': 'conv_0',
#   'platform': 'LinkedIn',
#   'connection_name': 'Bhavya Shah',
#   'message_sender': 'Vikas Reddy Venkannagari',
#   'message_date': '2025-05-08 01:08:00',
#   'message_text': 'Hey Bhavya, I’m Vikas, a current grad student at UMBC, applying for Software Engineer in Test role at Apple. I’d love your take—would you be open to a referral? I bring over 1.5 years of relevant experience and am happy to share my resume. Thanks!',
#   'connection_title': 'MLE @ Apple'},
#  {'message_id': 'messg_3',
#   'conversation_id': 'conv_1',
#   'platform': 'LinkedIn',
#   'connection_name': 'Bhavya Shah',
#   'message_sender': 'Bhavya Shah',
#   'message_date': '2025-05-08 01:08:00',
#   'message_text': 'Sure. Can you send me the job role and resume at shahbhavyan12@gmail.com',
#   'connection_title': 'MLE @ Apple'},
#  {'message_id': 'messg_3',
#   'conversation_id': 'conv_2',
#   'platform': 'LinkedIn',
#   'connection_name': 'Bhavya Shah',
#   'message_sender': 'Vikas Reddy Venkannagari',
#   'message_date': '2025-05-09 13:12:00',
#   'message_text': 'Hey Bhavya Shah, I have sent you an email.',
#   'connection_title': 'MLE @ Apple'},
#  {'message_id': 'messg_3',
#   'conversation_id': 'conv_3',
#   'platform': 'LinkedIn',
#   'connection_name': 'Bhavya Shah',
#   'message_sender': 'Vikas Reddy Venkannagari',
#   'message_date': '2025-05-09 13:12:00',
#   'message_text': 'I also noticed that Apple has just opened machine-learning roles for recent graduates. I’m finishing an exciting LLM-based project this week—would you be willing to refer me for one of those positions as well?',
#   'connection_title': 'MLE @ Apple'},
#  {'message_id': 'messg_4',
#   'conversation_id': 'conv_0',
#   'platform': 'LinkedIn',
#   'connection_name': 'Tolu Atanda',
#   'message_sender': 'Vikas Reddy Venkannagari',
#   'message_date': '2025-05-05 09:10:00',
#   'message_text': 'Hey Tolu, I’m Vikas, a current grad student at UMBC, applying for Software Engineer role at Capital Group. As a fellow UMBC alum, I’d love your take—would you be open to a referral? I bring over 1.5 years of relevant experience and am happy to share my resume. Thanks!',
#   'connection_title': 'Manager, Quantitative Analysis at Capital One'},
#  {'message_id': 'messg_4',
#   'conversation_id': 'conv_1',
#   'platform': 'LinkedIn',
#   'connection_name': 'Tolu Atanda',
#   'message_sender': 'Tolu Atanda',
#   'message_date': '2025-05-05 09:10:00',
#   'message_text': 'Hi, Vikas Reddy',
#   'connection_title': 'Manager, Quantitative Analysis at Capital One'},
#  {'message_id': 'messg_4',
#   'conversation_id': 'conv_2',
#   'platform': 'LinkedIn',
#   'connection_name': 'Tolu Atanda',
#   'message_sender': 'Tolu Atanda',
#   'message_date': '2025-05-05 09:10:00',
#   'message_text': 'Sure thing ',
#   'connection_title': 'Manager, Quantitative Analysis at Capital One'},
#  {'message_id': 'messg_4',
#   'conversation_id': 'conv_3',
#   'platform': 'LinkedIn',
#   'connection_name': 'Tolu Atanda',
#   'message_sender': 'Tolu Atanda',
#   'message_date': '2025-05-05 09:10:00',
#   'message_text': 'Share the role with me ',
#   'connection_title': 'Manager, Quantitative Analysis at Capital One'},
#  {'message_id': 'messg_4',
#   'conversation_id': 'conv_4',
#   'platform': 'LinkedIn',
#   'connection_name': 'Tolu Atanda',
#   'message_sender': 'Vikas Reddy Venkannagari',
#   'message_date': '2025-05-05 09:10:00',
#   'message_text': 'Thanks Tolu, for your reply; let me fetch the details',
#   'connection_title': 'Manager, Quantitative Analysis at Capital One'},
#  {'message_id': 'messg_4',
#   'conversation_id': 'conv_5',
#   'platform': 'LinkedIn',
#   'connection_name': 'Tolu Atanda',
#   'message_sender': 'Vikas Reddy Venkannagari',
#   'message_date': '2025-05-05 09:10:00',
#   'message_text': 'Job id: R213949, It is a Senior Data Scientist Position',
#   'connection_title': 'Manager, Quantitative Analysis at Capital One'},
#  {'message_id': 'messg_4',
#   'conversation_id': 'conv_6',
#   'platform': 'LinkedIn',
#   'connection_name': 'Tolu Atanda',
#   'message_sender': 'Vikas Reddy Venkannagari',
#   'message_date': '2025-05-05 09:10:00',
#   'message_text': 'Hey Tolu, I’ve attached my resume along with a recommendation letter from my professor. If you have the opportunity, I would be very grateful if you could refer me or forward my materials to the appropriate hiring manager. \n \n \nThanks for your support.',
#   'connection_title': 'Manager, Quantitative Analysis at Capital One'},
#  {'message_id': 'messg_4',
#   'conversation_id': 'conv_7',
#   'platform': 'LinkedIn',
#   'connection_name': 'Tolu Atanda',
#   'message_sender': 'Tolu Atanda',
#   'message_date': '2025-05-06 10:33:00',
#   'message_text': 'Hey Vikas \nJust sent the referral ',
#   'connection_title': 'Manager, Quantitative Analysis at Capital One'},
#  {'message_id': 'messg_4',
#   'conversation_id': 'conv_8',
#   'platform': 'LinkedIn',
#   'connection_name': 'Tolu Atanda',
#   'message_sender': 'Vikas Reddy Venkannagari',
#   'message_date': '2025-05-06 10:33:00',
#   'message_text': 'thanks a lot',
#   'connection_title': 'Manager, Quantitative Analysis at Capital One'},
#  {'message_id': 'messg_4',
#   'conversation_id': 'conv_9',
#   'platform': 'LinkedIn',
#   'connection_name': 'Tolu Atanda',
#   'message_sender': 'Vikas Reddy Venkannagari',
#   'message_date': '2025-05-07 14:27:00',
#   'message_text': 'Hey Tolu, I have tuned my resume and applied for the job, thanks again for the referral.',
#   'connection_title': 'Manager, Quantitative Analysis at Capital One'},
#  {'message_id': 'messg_5',
#   'conversation_id': 'conv_0',
#   'platform': 'LinkedIn',
#   'connection_name': 'Justin Hilleary',
#   'message_sender': 'Vikas Reddy Venkannagari',
#   'message_date': '2025-05-06 21:03:00',
#   'message_text': 'Hey Justin, I’m Vikas, a current grad student at UMBC, applying for AI Solutions Engineer role at Thomson Reuters. I’d love your take—would you be open to a referral? I bring over 1.5 years of relevant experience and am happy to share my resume. Thanks!',
#   'connection_title': 'Software Engineer & Scrum Master at Thomson Reuters'},
#  {'message_id': 'messg_6',
#   'conversation_id': 'conv_0',
#   'platform': 'LinkedIn',
#   'connection_name': 'Aishvarya Singh',
#   'message_sender': 'Vikas Reddy Venkannagari',
#   'message_date': '2025-05-06 19:02:00',
#   'message_text': 'Hey Aishvarya, I’m Vikas, a current grad student at UMBC, applying for Software Engineer in Test role at Apple. I’d love your take—would you be open to a referral? I bring over 1.5 years of relevant experience and am happy to share my resume. Thanks!',
#   'connection_title': 'Engineering at Apple | Ex-Meta, Ex-Google | Stanford AI'},
#  {'message_id': 'messg_7',
#   'conversation_id': 'conv_0',
#   'platform': 'LinkedIn',
#   'connection_name': 'Elton Gbollie',
#   'message_sender': 'Vikas Reddy Venkannagari',
#   'message_date': '2025-05-06 18:53:00',
#   'message_text': 'Hey Elton, I’m Vikas, a current grad student at UMBC, applying for Software Engineer in Test role at Apple. I’d love your take—would you be open to a referral? I bring over 1.5 years of relevant experience and am happy to share my resume. Thanks!',
#   'connection_title': 'Software Engineer at Apple'},
#  {'message_id': 'messg_8',
#   'conversation_id': 'conv_0',
#   'platform': 'LinkedIn',
#   'connection_name': 'Armando Taveras’ profile',
#   'message_sender': 'Vikas Reddy Venkannagari',
#   'message_date': '2025-05-06 16:53:00',
#   'message_text': 'Hey Armando, I’m Vikas, a current grad student at UMBC, applying for Software Engineer in Test role at Apple. I’d love your take—would you be open to a referral? I bring over 1.5 years of relevant experience and am happy to share my resume. Thanks!',
#   'connection_title': 'Software Engineer @ Apple'},
#  {'message_id': 'messg_9',
#   'conversation_id': 'conv_0',
#   'platform': 'LinkedIn',
#   'connection_name': 'Rishabh Bassi',
#   'message_sender': 'Vikas Reddy Venkannagari',
#   'message_date': '2025-05-06 16:31:00',
#   'message_text': 'Hey Rishabh, I’m Vikas, a current grad student at UMBC, applying for Software Engineer in Test role at Apple. I’d love your take—would you be open to a referral? I bring over 1.5 years of relevant experience and am happy to share my resume. Thanks!',
#   'connection_title': 'ML Engineer @ Apple | Former Intern @ LinkedIn & AMD | MS CS - TAMU | Ex-Senior Engineer @ Western Digital'},
#  {'message_id': 'messg_10',
#   'conversation_id': 'conv_0',
#   'platform': 'LinkedIn',
#   'connection_name': 'Vincent Reid',
#   'message_sender': 'Vikas Reddy Venkannagari',
#   'message_date': '2025-05-06 16:18:00',
#   'message_text': 'Hey Vincent, I’m Vikas, a current grad student at UMBC, applying for AI Solutions Engineer role at Thomson Reuters. I’d love your take—would you be open to a referral? I bring over 1.5 years of relevant experience and am happy to share my resume. Thanks!',
#   'connection_title': 'Talent Acquisition Partner at Thomson Reuters'},
#  {'message_id': 'messg_11',
#   'conversation_id': 'conv_0',
#   'platform': 'LinkedIn',
#   'connection_name': 'Akil Savvas’ profile',
#   'message_sender': 'Vikas Reddy Venkannagari',
#   'message_date': '2025-05-06 12:06:00',
#   'message_text': 'Hey Akil, I’m Vikas, a current grad student at UMBC, applying for AI Solutions Engineer role at Thomson Reuters. I’d love your take—would you be open to a referral? I bring over 1.5 years of relevant experience and am happy to share my resume. Thanks!',
#   'connection_title': 'Software Engineer Intern at Thomson Reuters | UW Madison CS/Math Student | UW Madison CS 544 Peer Mentor | UW Madison Residence Hall Math Tutor | UW Madison CS Researcher at Animal & Dairy Sciences'},
#  {'message_id': 'messg_12',
#   'conversation_id': 'conv_0',
#   'platform': 'LinkedIn',
#   'connection_name': 'Bonakolluru Ajay Kumar',
#   'message_sender': 'Vikas Reddy Venkannagari',
#   'message_date': '2025-05-06 11:46:00',
#   'message_text': 'Hey Bonakolluru, I’m Vikas, a current grad student at UMBC, applying for AI Solutions Engineer role at Thomson Reuters. I’d love your take—would you be open to a referral? I bring over 1.5 years of relevant experience and am happy to share my resume. Thanks!',
#   'connection_title': 'Full Stack Java Developer | Microservices | Spring Boot | AWS & Azure Cloud | Vue.js , React & Node.js | Kafka | DevOps & CI/CD | Agile Practitioner | Actively looking for new c2c oppurtunities'},
#  {'message_id': 'messg_13',
#   'conversation_id': 'conv_0',
#   'platform': 'LinkedIn',
#   'connection_name': 'Himanshi Arora',
#   'message_sender': 'Vikas Reddy Venkannagari',
#   'message_date': '2025-05-05 23:06:00',
#   'message_text': 'Hey Himanshi, I’m Vikas, a current grad student at UMBC, applying for Data Scientist role at Medline Industries. I’d love your take—would you be open to a referral? I bring over 1.5 years of relevant experience and am happy to share my resume. Thanks!',
#   'connection_title': 'Senior Data Architect at Medline Industries, Inc.'},
#  {'message_id': 'messg_14',
#   'conversation_id': 'conv_0',
#   'platform': 'LinkedIn',
#   'connection_name': 'Pooja Habbu',
#   'message_sender': 'Vikas Reddy Venkannagari',
#   'message_date': '2025-05-05 15:36:00',
#   'message_text': 'Hey Pooja, I’m Vikas, a current grad student at UMBC, applying for Data Scientist role at Itron. I’d love your take—would you be open to a referral? I bring over 1.5 years of relevant experience and am happy to share my resume. Thanks!',
#   'connection_title': 'Systems Test Engineer at Itron, Inc'},
#  {'message_id': 'messg_14',
#   'conversation_id': 'conv_1',
#   'platform': 'LinkedIn',
#   'connection_name': 'Pooja Habbu',
#   'message_sender': 'Pooja Habbu',
#   'message_date': '2025-05-05 15:36:00',
#   'message_text': 'Hi , I do suggest reaching out to someone with the same title as I’m fairly new here so the chances are slim . All the best ',
#   'connection_title': 'Systems Test Engineer at Itron, Inc'},
#  {'message_id': 'messg_14',
#   'conversation_id': 'conv_2',
#   'platform': 'LinkedIn',
#   'connection_name': 'Pooja Habbu',
#   'message_sender': 'Vikas Reddy Venkannagari',
#   'message_date': '2025-05-05 15:36:00',
#   'message_text': 'Thanks Pooja for the insights ',
#   'connection_title': 'Systems Test Engineer at Itron, Inc'},
#  {'message_id': 'messg_15',
#   'conversation_id': 'conv_0',
#   'platform': 'LinkedIn',
#   'connection_name': 'Pooja Habbu',
#   'message_sender': 'Vikas Reddy Venkannagari',
#   'message_date': '2025-05-05 15:36:00',
#   'message_text': 'Hey Pooja, I’m Vikas, a current grad student at UMBC, applying for Data Scientist role at Itron. I’d love your take—would you be open to a referral? I bring over 1.5 years of relevant experience and am happy to share my resume. Thanks!',
#   'connection_title': 'Systems Test Engineer at Itron, Inc'},
#  {'message_id': 'messg_16',
#   'conversation_id': 'conv_0',
#   'platform': 'LinkedIn',
#   'connection_name': 'Mattie Dew',
#   'message_sender': 'Vikas Reddy Venkannagari',
#   'message_date': '2025-05-05 09:54:00',
#   'message_text': 'Hey Mattie, I’m Vikas, a current grad student at UMBC, applying for Data Scientist role at Itron. I’d love your take—would you be open to a referral? I bring over 1.5 years of relevant experience and am happy to share my resume. Thanks!',
#   'connection_title': 'Building dream teams, one hire at a time! 🔎 Talent Acquisition Specialist @ Itron, Inc. | Full-Cycle Hiring Pro'},
#  {'message_id': 'messg_17',
#   'conversation_id': 'conv_0',
#   'platform': 'LinkedIn',
#   'connection_name': 'Devi Manaswi Kallam',
#   'message_sender': 'Vikas Reddy Venkannagari',
#   'message_date': '2025-05-03 18:45:00',
#   'message_text': 'Hey Devi, I’m Vikas, a current grad student at UMBC, applying for Data Analyst role at BlackRock. I’d love your take—would you be open to a referral? I bring over 1.5 years of relevant experience and am happy to share my resume. Thanks!',
#   'connection_title': 'Associate @BlackRock | Python, Big data, SQL, Data Ingestion, ETL, Spark, AWS, Tableau'},
#  {'message_id': 'messg_18',
#   'conversation_id': 'conv_0',
#   'platform': 'LinkedIn',
#   'connection_name': 'Xiaona (Eva) Ou',
#   'message_sender': 'Vikas Reddy Venkannagari',
#   'message_date': '2025-05-02 19:34:00',
#   'message_text': 'Hey Xiaona, I’m Vikas, a current grad student at UMBC, applying for Data Scientist role at Medline Industries. I’d love your take—would you be open to a referral? I bring over 1.5 years of relevant experience and am happy to share my resume. Thanks!',
#   'connection_title': 'Sales Analyst at Medline Industries, Inc.'},
#  {'message_id': 'messg_0',
#   'conversation_id': 'conv_0',
#   'platform': 'LinkedIn',
#   'connection_name': 'Namruth Thimmapuram',
#   'message_sender': 'Vikas Reddy Venkannagari',
#   'message_date': '2024-11-04 20:28:00',
#   'message_text': "Hi Namruth Goud,\n\nIt's been some time since we connected. We both studied at University of Maryland Baltimore County. How have you been?",
#   'connection_title': "Master's in Data Science @UMBC"},
#  {'message_id': 'messg_0',
#   'conversation_id': 'conv_1',
#   'platform': 'LinkedIn',
#   'connection_name': 'Namruth Thimmapuram',
#   'message_sender': 'Namruth Thimmapuram',
#   'message_date': '2024-11-10 23:25:00',
#   'message_text': 'Hi, Vikas Reddy',
#   'connection_title': "Master's in Data Science @UMBC"},
#  {'message_id': 'messg_0',
#   'conversation_id': 'conv_2',
#   'platform': 'LinkedIn',
#   'connection_name': 'Namruth Thimmapuram',
#   'message_sender': 'Namruth Thimmapuram',
#   'message_date': '2024-11-10 23:25:00',
#   'message_text': "I'm good",
#   'connection_title': "Master's in Data Science @UMBC"},
#  {'message_id': 'messg_0',
#   'conversation_id': 'conv_3',
#   'platform': 'LinkedIn',
#   'connection_name': 'Namruth Thimmapuram',
#   'message_sender': 'Namruth Thimmapuram',
#   'message_date': '2024-11-10 23:25:00',
#   'message_text': 'How about you?',
#   'connection_title': "Master's in Data Science @UMBC"},
#  {'message_id': 'messg_0',
#   'conversation_id': 'conv_4',
#   'platform': 'LinkedIn',
#   'connection_name': 'Namruth Thimmapuram',
#   'message_sender': 'Vikas Reddy Venkannagari',
#   'message_date': '2024-11-11 20:37:00',
#   'message_text': "I'm good, too",
#   'connection_title': "Master's in Data Science @UMBC"},
#  {'message_id': 'messg_0',
#   'conversation_id': 'conv_5',
#   'platform': 'LinkedIn',
#   'connection_name': 'Namruth Thimmapuram',
#   'message_sender': 'Vikas Reddy Venkannagari',
#   'message_date': '2024-11-15 22:42:00',
#   'message_text': 'profile pic bagunda ?',
#   'connection_title': "Master's in Data Science @UMBC"},
#  {'message_id': 'messg_0',
#   'conversation_id': 'conv_6',
#   'platform': 'LinkedIn',
#   'connection_name': 'Namruth Thimmapuram',
#   'message_sender': 'Vikas Reddy Venkannagari',
#   'message_date': '2024-11-15 22:56:00',
#   'message_text': 'baane extralu',
#   'connection_title': "Master's in Data Science @UMBC"},
#  {'message_id': 'messg_0',
#   'conversation_id': 'conv_7',
#   'platform': 'LinkedIn',
#   'connection_name': 'Namruth Thimmapuram',
#   'message_sender': 'Namruth Thimmapuram',
#   'message_date': '2024-11-16 08:37:00',
#   'message_text': 'Yeah',
#   'connection_title': "Master's in Data Science @UMBC"},
#  {'message_id': 'messg_0',
#   'conversation_id': 'conv_8',
#   'platform': 'LinkedIn',
#   'connection_name': 'Namruth Thimmapuram',
#   'message_sender': 'Vikas Reddy Venkannagari',
#   'message_date': '2025-01-09 19:50:00',
#   'message_text': '',
#   'connection_title': "Master's in Data Science @UMBC"},
#  {'message_id': 'messg_0',
#   'conversation_id': 'conv_9',
#   'platform': 'LinkedIn',
#   'connection_name': 'Namruth Thimmapuram',
#   'message_sender': 'Vikas Reddy Venkannagari',
#   'message_date': '2025-01-14 15:48:00',
#   'message_text': '',
#   'connection_title': "Master's in Data Science @UMBC"},
#  {'message_id': 'messg_0',
#   'conversation_id': 'conv_10',
#   'platform': 'LinkedIn',
#   'connection_name': 'Namruth Thimmapuram',
#   'message_sender': 'Vikas Reddy Venkannagari',
#   'message_date': '2025-01-14 15:49:00',
#   'message_text': '',
#   'connection_title': "Master's in Data Science @UMBC"},
#  {'message_id': 'messg_0',
#   'conversation_id': 'conv_11',
#   'platform': 'LinkedIn',
#   'connection_name': 'Namruth Thimmapuram',
#   'message_sender': 'Vikas Reddy Venkannagari',
#   'message_date': '2025-01-14 15:49:00',
#   'message_text': 'Rey, idi chaduvu, clarity vastadi',
#   'connection_title': "Master's in Data Science @UMBC"},
#  {'message_id': 'messg_0',
#   'conversation_id': 'conv_12',
#   'platform': 'LinkedIn',
#   'connection_name': 'Namruth Thimmapuram',
#   'message_sender': 'Namruth Thimmapuram',
#   'message_date': '2025-01-28 13:40:00',
#   'message_text': 'endi ra adantha',
#   'connection_title': "Master's in Data Science @UMBC"},
#  {'message_id': 'messg_0',
#   'conversation_id': 'conv_13',
#   'platform': 'LinkedIn',
#   'connection_name': 'Namruth Thimmapuram',
#   'message_sender': 'Vikas Reddy Venkannagari',
#   'message_date': '2025-05-09 19:48:00',
#   'message_text': 'Hi ',
#   'connection_title': "Master's in Data Science @UMBC"},
#  {'message_id': 'messg_0',
#   'conversation_id': 'conv_14',
#   'platform': 'LinkedIn',
#   'connection_name': 'Namruth Thimmapuram',
#   'message_sender': 'Namruth Thimmapuram',
#   'message_date': '2025-05-09 19:48:00',
#   'message_text': 'How are you?',
#   'connection_title': "Master's in Data Science @UMBC"},
#  {'message_id': 'messg_0',
#   'conversation_id': 'conv_15',
#   'platform': 'LinkedIn',
#   'connection_name': 'Namruth Thimmapuram',
#   'message_sender': 'Vikas Reddy Venkannagari',
#   'message_date': '2025-05-09 19:48:00',
#   'message_text': 'What are you doing ',
#   'connection_title': "Master's in Data Science @UMBC"},
#  {'message_id': 'messg_0',
#   'conversation_id': 'conv_16',
#   'platform': 'LinkedIn',
#   'connection_name': 'Namruth Thimmapuram',
#   'message_sender': 'Namruth Thimmapuram',
#   'message_date': '2025-05-09 19:48:00',
#   'message_text': 'Working',
#   'connection_title': "Master's in Data Science @UMBC"},
#  {'message_id': 'messg_0',
#   'conversation_id': 'conv_17',
#   'platform': 'LinkedIn',
#   'connection_name': 'Namruth Thimmapuram',
#   'message_sender': 'Namruth Thimmapuram',
#   'message_date': '2025-05-09 19:48:00',
#   'message_text': 'And you?',
#   'connection_title': "Master's in Data Science @UMBC"},
#  {'message_id': 'messg_0',
#   'conversation_id': 'conv_18',
#   'platform': 'LinkedIn',
#   'connection_name': 'Namruth Thimmapuram',
#   'message_sender': 'Vikas Reddy Venkannagari',
#   'message_date': '2025-05-09 19:48:00',
#   'message_text': "Let's gor for a walk ?",
#   'connection_title': "Master's in Data Science @UMBC"},
#  {'message_id': 'messg_0',
#   'conversation_id': 'conv_19',
#   'platform': 'LinkedIn',
#   'connection_name': 'Namruth Thimmapuram',
#   'message_sender': 'Vikas Reddy Venkannagari',
#   'message_date': '2025-05-09 19:48:00',
#   'message_text': 'Now ?',
#   'connection_title': "Master's in Data Science @UMBC"},
#  {'message_id': 'messg_0',
#   'conversation_id': 'conv_20',
#   'platform': 'LinkedIn',
#   'connection_name': 'Namruth Thimmapuram',
#   'message_sender': 'Vikas Reddy Venkannagari',
#   'message_date': '2025-05-09 19:48:00',
#   'message_text': 'Thank you',
#   'connection_title': "Master's in Data Science @UMBC"},
#  {'message_id': 'messg_0',
#   'conversation_id': 'conv_21',
#   'platform': 'LinkedIn',
#   'connection_name': 'Namruth Thimmapuram',
#   'message_sender': 'Namruth Thimmapuram',
#   'message_date': '2025-05-09 19:48:00',
#   'message_text': 'Right now',
#   'connection_title': "Master's in Data Science @UMBC"},
#  {'message_id': 'messg_0',
#   'conversation_id': 'conv_22',
#   'platform': 'LinkedIn',
#   'connection_name': 'Namruth Thimmapuram',
#   'message_sender': 'Vikas Reddy Venkannagari',
#   'message_date': '2025-05-09 19:48:00',
#   'message_text': 'Yeah',
#   'connection_title': "Master's in Data Science @UMBC"},
#  {'message_id': 'messg_0',
#   'conversation_id': 'conv_23',
#   'platform': 'LinkedIn',
#   'connection_name': 'Namruth Thimmapuram',
#   'message_sender': 'Namruth Thimmapuram',
#   'message_date': '2025-05-09 19:48:00',
#   'message_text': 'Goodbye',
#   'connection_title': "Master's in Data Science @UMBC"},
#  {'message_id': 'messg_1',
#   'conversation_id': 'conv_0',
#   'platform': 'LinkedIn',
#   'connection_name': 'Haixu Leng',
#   'message_sender': 'Vikas Reddy Venkannagari',
#   'message_date': '2025-05-09 19:36:00',
#   'message_text': 'Hey Haixu, I’m Vikas, a current grad student at UMBC, applying for Algorithm Engineer role at KLA. As a fellow UMBC alum, I’d love your take—would you be open to a referral? I bring over 1.5 years of relevant experience and am happy to share my resume. Thanks!',
#   'connection_title': 'Algorithm Engineer'},
#  {'message_id': 'messg_2',
#   'conversation_id': 'conv_0',
#   'platform': 'LinkedIn',
#   'connection_name': 'Sameer Kibey',
#   'message_sender': 'Vikas Reddy Venkannagari',
#   'message_date': '2024-04-05 23:31:00',
#   'message_text': 'Hi, \n\nI am currently enrolled in MS program (Data science) at University of Maryland, Baltimore County, and looking for summer 2024 internship opportunities, Is there any position available in your team? Can you help me out here. \n\nThanks and regards,\nVikas Reddy',
#   'connection_title': 'Software Engineering Leader | oneAPI Developer SW | Streaming Media (Video/Audio) and AI | Technical and Organizational Leadership'},
#  {'message_id': 'messg_2',
#   'conversation_id': 'conv_1',
#   'platform': 'LinkedIn',
#   'connection_name': 'Sameer Kibey',
#   'message_sender': 'Sameer Kibey',
#   'message_date': '2024-04-06 13:54:00',
#   'message_text': 'Hi Vikas, my team is not hiring at the moment. But I will keep an eye on any opportunities. Suggest you to add your resume when you contact people, and briefly mention key competencies/core skills. Thus they can see what areas you will be a good fit in. ',
#   'connection_title': 'Software Engineering Leader | oneAPI Developer SW | Streaming Media (Video/Audio) and AI | Technical and Organizational Leadership'},
#  {'message_id': 'messg_2',
#   'conversation_id': 'conv_2',
#   'platform': 'LinkedIn',
#   'connection_name': 'Sameer Kibey',
#   'message_sender': 'Vikas Reddy Venkannagari',
#   'message_date': '2024-04-06 15:25:00',
#   'message_text': 'hey sameer, \n \nI am currently volunteering at a research lab in UMBC. Where we developing a transformer based model to predict the emotions by fusing EEG signal data and facial features, targeted publishing date is less than 2 months. Coming to my interests I am interested in computer vision and nlp based tasks. I am attaching my resume for your reference.(Edited)',
#   'connection_title': 'Software Engineering Leader | oneAPI Developer SW | Streaming Media (Video/Audio) and AI | Technical and Organizational Leadership'},
#  {'message_id': 'messg_2',
#   'conversation_id': 'conv_3',
#   'platform': 'LinkedIn',
#   'connection_name': 'Sameer Kibey',
#   'message_sender': 'Vikas Reddy Venkannagari',
#   'message_date': '2024-04-09 23:54:00',
#   'message_text': 'Hey Sameer, \n \nI found an internship opportunity which I believe is a perfect fit for my background. The job is : JR026142, role of "Foundational AI Research Intern". Can you please refer me to this position. \n \nI am attaching my resume for your reference,',
#   'connection_title': 'Software Engineering Leader | oneAPI Developer SW | Streaming Media (Video/Audio) and AI | Technical and Organizational Leadership'},
#  {'message_id': 'messg_2',
#   'conversation_id': 'conv_4',
#   'platform': 'LinkedIn',
#   'connection_name': 'Sameer Kibey',
#   'message_sender': 'Sameer Kibey',
#   'message_date': '2024-06-02 17:12:00',
#   'message_text': 'Hello Vikas, I missed responding to your message. My apologies. Are you still looking for summer internship role? I can forward your resume to the hiring manager for JR026142. However, on your resume the LinkedIn link is not valid. Suggest you to correct that. Also add a tag line at the top of the resume, that helps the reader understand what kind of role you are looking for. Something like - "Experienced graduate student looking for an internship in AI/ML/Deep Learning <or add other areas here> for Summer 2024".',
#   'connection_title': 'Software Engineering Leader | oneAPI Developer SW | Streaming Media (Video/Audio) and AI | Technical and Organizational Leadership'},
#  {'message_id': 'messg_2',
#   'conversation_id': 'conv_5',
#   'platform': 'LinkedIn',
#   'connection_name': 'Sameer Kibey',
#   'message_sender': 'Vikas Reddy Venkannagari',
#   'message_date': '2024-06-02 17:12:00',
#   'message_text': 'Sure Sameer, I will make the changes.',
#   'connection_title': 'Software Engineering Leader | oneAPI Developer SW | Streaming Media (Video/Audio) and AI | Technical and Organizational Leadership'},
#  {'message_id': 'messg_2',
#   'conversation_id': 'conv_6',
#   'platform': 'LinkedIn',
#   'connection_name': 'Sameer Kibey',
#   'message_sender': 'Vikas Reddy Venkannagari',
#   'message_date': '2024-07-13 15:56:00',
#   'message_text': 'Hey Sameer, I have made suitable changes and also updated my resume with my latest projects. \n \nI believe the above position is no longer open, can you please refer to the role Multimodal AI Research Intern, Job ID JR0266069. (fall 2024 internship)\n \nI would also love some comments to improve on my resume.',
#   'connection_title': 'Software Engineering Leader | oneAPI Developer SW | Streaming Media (Video/Audio) and AI | Technical and Organizational Leadership'},
#  {'message_id': 'messg_2',
#   'conversation_id': 'conv_7',
#   'platform': 'LinkedIn',
#   'connection_name': 'Sameer Kibey',
#   'message_sender': 'Sameer Kibey',
#   'message_date': '2024-07-13 21:56:00',
#   'message_text': 'I will submit referral for the internship position.. resume looks fine to me. ',
#   'connection_title': 'Software Engineering Leader | oneAPI Developer SW | Streaming Media (Video/Audio) and AI | Technical and Organizational Leadership'},
#  {'message_id': 'messg_2',
#   'conversation_id': 'conv_8',
#   'platform': 'LinkedIn',
#   'connection_name': 'Sameer Kibey',
#   'message_sender': 'Vikas Reddy Venkannagari',
#   'message_date': '2024-07-13 21:57:00',
#   'message_text': 'Thank you very much',
#   'connection_title': 'Software Engineering Leader | oneAPI Developer SW | Streaming Media (Video/Audio) and AI | Technical and Organizational Leadership'},
#  {'message_id': 'messg_2',
#   'conversation_id': 'conv_9',
#   'platform': 'LinkedIn',
#   'connection_name': 'Sameer Kibey',
#   'message_sender': 'Sameer Kibey',
#   'message_date': '2024-07-16 20:37:00',
#   'message_text': 'I submitted the referral, but note that the position lists minimum requirement as PhD candidate. I am not sure how flexible they would be to consider MS candidates. Anyway, all the best!',
#   'connection_title': 'Software Engineering Leader | oneAPI Developer SW | Streaming Media (Video/Audio) and AI | Technical and Organizational Leadership'},
#  {'message_id': 'messg_2',
#   'conversation_id': 'conv_10',
#   'platform': 'LinkedIn',
#   'connection_name': 'Sameer Kibey',
#   'message_sender': 'Vikas Reddy Venkannagari',
#   'message_date': '2024-07-16 20:38:00',
#   'message_text': 'Yeah, and I saw there were no other fall 2024 internship opportunities',
#   'connection_title': 'Software Engineering Leader | oneAPI Developer SW | Streaming Media (Video/Audio) and AI | Technical and Organizational Leadership'},
#  {'message_id': 'messg_2',
#   'conversation_id': 'conv_11',
#   'platform': 'LinkedIn',
#   'connection_name': 'Sameer Kibey',
#   'message_sender': 'Vikas Reddy Venkannagari',
#   'message_date': '2024-07-16 20:38:00',
#   'message_text': 'Thanks again, for the referral. ',
#   'connection_title': 'Software Engineering Leader | oneAPI Developer SW | Streaming Media (Video/Audio) and AI | Technical and Organizational Leadership'},
#  {'message_id': 'messg_2',
#   'conversation_id': 'conv_12',
#   'platform': 'LinkedIn',
#   'connection_name': 'Sameer Kibey',
#   'message_sender': 'Vikas Reddy Venkannagari',
#   'message_date': '2025-04-14 10:24:00',
#   'message_text': "Hi Sameer, hope you're doing well.\nThanks again for the earlier referral.\n\nWould it be a ridiculous idea to ask if you or your team are hiring for other data/software roles?",
#   'connection_title': 'Software Engineering Leader | oneAPI Developer SW | Streaming Media (Video/Audio) and AI | Technical and Organizational Leadership'},
#  {'message_id': 'messg_2',
#   'conversation_id': 'conv_13',
#   'platform': 'LinkedIn',
#   'connection_name': 'Sameer Kibey',
#   'message_sender': 'Sameer Kibey',
#   'message_date': '2025-05-09 12:18:00',
#   'message_text': 'Hello Vikas, hiring is slow at Intel at the moment. My team is not hiring for full time roles. I can send your resume to my contacts at Nvidia and Amazon that work in AI. Send me your latest resume.',
#   'connection_title': 'Software Engineering Leader | oneAPI Developer SW | Streaming Media (Video/Audio) and AI | Technical and Organizational Leadership'},
#  {'message_id': 'messg_2',
#   'conversation_id': 'conv_14',
#   'platform': 'LinkedIn',
#   'connection_name': 'Sameer Kibey',
#   'message_sender': 'Vikas Reddy Venkannagari',
#   'message_date': '2025-05-09 12:18:00',
# ...
#   'connection_name': 'Pratham Reddy',
#   'message_sender': 'Vikas Reddy Venkannagari',
#   'message_date': '2025-04-21 12:23:00',
#   'message_text': 'Hey pratham, thanks for the quick reply, they removed the job 1 hour ago.(Edited)',
#   'connection_title': 'IT Auditor at EchoStar Corporation | SOX Compliance | GRC | Internal Audits | Data Analytics | AWS Certified | Cloud Computing Enthusiast'},
#  {'message_id': 'messg_72',
#   'conversation_id': 'conv_3',
#   'platform': 'LinkedIn',
#   'connection_name': 'Pratham Reddy',
#   'message_sender': 'Vikas Reddy Venkannagari',
#   'message_date': '2025-04-21 12:23:00',
#   'message_text': 'And it was posted 1 day ago',
#   'connection_title': 'IT Auditor at EchoStar Corporation | SOX Compliance | GRC | Internal Audits | Data Analytics | AWS Certified | Cloud Computing Enthusiast'},
#  {'message_id': 'messg_72',
#   'conversation_id': 'conv_4',
#   'platform': 'LinkedIn',
#   'connection_name': 'Pratham Reddy',
#   'message_sender': 'Pratham Reddy',
#   'message_date': '2025-04-21 12:24:00',
#   'message_text': 'Okay, let me know if you come across any relevant roles in future ',
#   'connection_title': 'IT Auditor at EchoStar Corporation | SOX Compliance | GRC | Internal Audits | Data Analytics | AWS Certified | Cloud Computing Enthusiast'},
#  {'message_id': 'messg_72',
#   'conversation_id': 'conv_5',
#   'platform': 'LinkedIn',
#   'connection_name': 'Pratham Reddy',
#   'message_sender': 'Vikas Reddy Venkannagari',
#   'message_date': '2025-04-21 12:24:00',
#   'message_text': 'Thanks, will do',
#   'connection_title': 'IT Auditor at EchoStar Corporation | SOX Compliance | GRC | Internal Audits | Data Analytics | AWS Certified | Cloud Computing Enthusiast'},
#  {'message_id': 'messg_73',
#   'conversation_id': 'conv_0',
#   'platform': 'LinkedIn',
#   'connection_name': 'Sindhu Sree Aita',
#   'message_sender': 'Vikas Reddy Venkannagari',
#   'message_date': '2025-04-21 11:52:00',
#   'message_text': 'Hey Sindhu, I’m Vikas, a current grad student at UMBC, applying for Software Engineer role at Salesforce. As a fellow UMBC alum, I’d love your take—would you be open to a referral? I bring over 1.5 years of relevant experience and am happy to share my resume. Thanks!',
#   'connection_title': 'Software Engineer at Salesforce | MS CS@ASU | Amazon | NIT Surat'},
#  {'message_id': 'messg_74',
#   'conversation_id': 'conv_0',
#   'platform': 'LinkedIn',
#   'connection_name': 'Kristina Callahan',
#   'message_sender': 'Vikas Reddy Venkannagari',
#   'message_date': '2025-04-21 11:22:00',
#   'message_text': "Hi Krishtina,\n \nI hope you're doing well! I came across the Software Developer I role at CNH Industrial and was really excited about the opportunity. With experience in cloud automation, backend development, and a strong foundation in Python, AWS, and CI/CD tools, I believe I’d be a great fit for the role.\n \nI’ve recently applied and would love the chance to connect and briefly discuss how I can contribute to your team.\n \nThanks for your time, and I hope to hear from you soon!\n \nVikas Reddy",
#   'connection_title': 'Passionate about Learning & Development | DEI Advocate | SHRM-CP | MBA | M.Ed'},
#  {'message_id': 'messg_75',
#   'conversation_id': 'conv_0',
#   'platform': 'LinkedIn',
#   'connection_name': 'Manujith Prakash',
#   'message_sender': 'Vikas Reddy Venkannagari',
#   'message_date': '2025-04-21 09:02:00',
#   'message_text': 'Hey Manujith, I’m Vikas, a current grad student at UMBC, applying for Software Engineer role at Echostar. I’d love your take—would you be open to a referral? I bring over 1.5 years of relevant experience and am happy to share my resume. Thanks!',
#   'connection_title': 'Data Scientist - Echostar | MLB | Pennsylvania State University | Ernst & Young'},
#  {'message_id': 'messg_75',
#   'conversation_id': 'conv_1',
#   'platform': 'LinkedIn',
#   'connection_name': 'Manujith Prakash',
#   'message_sender': 'Manujith Prakash',
#   'message_date': '2025-04-21 09:03:00',
#   'message_text': 'Hi Vikas',
#   'connection_title': 'Data Scientist - Echostar | MLB | Pennsylvania State University | Ernst & Young'},
#  {'message_id': 'messg_75',
#   'conversation_id': 'conv_2',
#   'platform': 'LinkedIn',
#   'connection_name': 'Manujith Prakash',
#   'message_sender': 'Manujith Prakash',
#   'message_date': '2025-04-21 09:03:00',
#   'message_text': 'I can refer you ',
#   'connection_title': 'Data Scientist - Echostar | MLB | Pennsylvania State University | Ernst & Young'},
#  {'message_id': 'messg_75',
#   'conversation_id': 'conv_3',
#   'platform': 'LinkedIn',
#   'connection_name': 'Manujith Prakash',
#   'message_sender': 'Manujith Prakash',
#   'message_date': '2025-04-21 09:03:00',
#   'message_text': 'Please share your resume and contact details ',
#   'connection_title': 'Data Scientist - Echostar | MLB | Pennsylvania State University | Ernst & Young'},
#  {'message_id': 'messg_75',
#   'conversation_id': 'conv_4',
#   'platform': 'LinkedIn',
#   'connection_name': 'Manujith Prakash',
#   'message_sender': 'Manujith Prakash',
#   'message_date': '2025-04-21 09:03:00',
#   'message_text': 'And job ID',
#   'connection_title': 'Data Scientist - Echostar | MLB | Pennsylvania State University | Ernst & Young'},
#  {'message_id': 'messg_75',
#   'conversation_id': 'conv_5',
#   'platform': 'LinkedIn',
#   'connection_name': 'Manujith Prakash',
#   'message_sender': 'Vikas Reddy Venkannagari',
#   'message_date': '2025-04-21 09:05:00',
#   'message_text': 'Thanks Manujith, for the quick reply, The job id being: \n R0004668, and below attached is my resume. email: vikasreddy0705@gmail.com',
#   'connection_title': 'Data Scientist - Echostar | MLB | Pennsylvania State University | Ernst & Young'},
#  {'message_id': 'messg_75',
#   'conversation_id': 'conv_6',
#   'platform': 'LinkedIn',
#   'connection_name': 'Manujith Prakash',
#   'message_sender': 'Vikas Reddy Venkannagari',
#   'message_date': '2025-04-21 09:07:00',
#   'message_text': 'phone: 443-992-2554',
#   'connection_title': 'Data Scientist - Echostar | MLB | Pennsylvania State University | Ernst & Young'},
#  {'message_id': 'messg_75',
#   'conversation_id': 'conv_7',
#   'platform': 'LinkedIn',
#   'connection_name': 'Manujith Prakash',
#   'message_sender': 'Manujith Prakash',
#   'message_date': '2025-04-21 09:11:00',
#   'message_text': 'Your address?',
#   'connection_title': 'Data Scientist - Echostar | MLB | Pennsylvania State University | Ernst & Young'},
#  {'message_id': 'messg_75',
#   'conversation_id': 'conv_8',
#   'platform': 'LinkedIn',
#   'connection_name': 'Manujith Prakash',
#   'message_sender': 'Vikas Reddy Venkannagari',
#   'message_date': '2025-04-21 09:12:00',
#   'message_text': '1014 Courtney road, Halethorpe, MD',
#   'connection_title': 'Data Scientist - Echostar | MLB | Pennsylvania State University | Ernst & Young'},
#  {'message_id': 'messg_75',
#   'conversation_id': 'conv_9',
#   'platform': 'LinkedIn',
#   'connection_name': 'Manujith Prakash',
#   'message_sender': 'Manujith Prakash',
#   'message_date': '2025-04-21 10:33:00',
#   'message_text': 'This job posting for R0004668 has been closed',
#   'connection_title': 'Data Scientist - Echostar | MLB | Pennsylvania State University | Ernst & Young'},
#  {'message_id': 'messg_75',
#   'conversation_id': 'conv_10',
#   'platform': 'LinkedIn',
#   'connection_name': 'Manujith Prakash',
#   'message_sender': 'Manujith Prakash',
#   'message_date': '2025-04-21 10:33:00',
#   'message_text': 'If you find any other open role, let me know',
#   'connection_title': 'Data Scientist - Echostar | MLB | Pennsylvania State University | Ernst & Young'},
#  {'message_id': 'messg_75',
#   'conversation_id': 'conv_11',
#   'platform': 'LinkedIn',
#   'connection_name': 'Manujith Prakash',
#   'message_sender': 'Vikas Reddy Venkannagari',
#   'message_date': '2025-04-21 10:36:00',
#   'message_text': "Oh, ok; I'll fetch a job that fits me",
#   'connection_title': 'Data Scientist - Echostar | MLB | Pennsylvania State University | Ernst & Young'},
#  {'message_id': 'messg_76',
#   'conversation_id': 'conv_0',
#   'platform': 'LinkedIn',
#   'connection_name': 'sachin sharma',
#   'message_sender': 'Vikas Reddy Venkannagari',
#   'message_date': '2025-04-21 09:50:00',
#   'message_text': 'Hey sachin, I’m Vikas, a current grad student at UMBC, applying for Software Engineer role at wex. I’d love your take—would you be open to a referral? I bring over 1.5 years of relevant experience and am happy to share my resume. Thanks!.(Edited)',
#   'connection_title': 'Director of Software Engineering at WEX | Ex-Amazon | Ex-Microsoft'},
#  {'message_id': 'messg_77',
#   'conversation_id': 'conv_0',
#   'platform': 'LinkedIn',
#   'connection_name': 'Shvetan Katta',
#   'message_sender': 'Vikas Reddy Venkannagari',
#   'message_date': '2025-04-20 14:53:00',
#   'message_text': 'Hey Shvetan, I’m Vikas, a current grad student at UMBC, applying for Software Engineer role at Salesforce. As a fellow UMBC alum, I’d love your take—would you be open to a referral? I bring over 1.5 years of relevant experience and am happy to share my resume. Thanks!',
#   'connection_title': 'Software @ Salesforce'},
#  {'message_id': 'messg_78',
#   'conversation_id': 'conv_0',
#   'platform': 'LinkedIn',
#   'connection_name': 'Poojitha Emani',
#   'message_sender': 'Vikas Reddy Venkannagari',
#   'message_date': '2024-06-26 00:30:00',
#   'message_text': '',
#   'connection_title': 'clapping hands'},
#  {'message_id': 'messg_78',
#   'conversation_id': 'conv_1',
#   'platform': 'LinkedIn',
#   'connection_name': 'Poojitha Emani',
#   'message_sender': 'Vikas Reddy Venkannagari',
#   'message_date': '2025-02-27 19:04:00',
#   'message_text': '',
#   'connection_title': 'clapping hands'},
#  {'message_id': 'messg_78',
#   'conversation_id': 'conv_2',
#   'platform': 'LinkedIn',
#   'connection_name': 'Poojitha Emani',
#   'message_sender': 'Vikas Reddy Venkannagari',
#   'message_date': '2025-03-08 17:53:00',
#   'message_text': '',
#   'connection_title': 'clapping hands'},
#  {'message_id': 'messg_78',
#   'conversation_id': 'conv_3',
#   'platform': 'LinkedIn',
#   'connection_name': 'Poojitha Emani',
#   'message_sender': 'Vikas Reddy Venkannagari',
#   'message_date': '2025-03-10 11:50:00',
#   'message_text': 'https://www.linkedin.com/posts/california-pizza-kitchen_california-pizza-kitchen-activity-7290760784530288641-2Kav',
#   'connection_title': 'clapping hands'},
#  {'message_id': 'messg_78',
#   'conversation_id': 'conv_4',
#   'platform': 'LinkedIn',
#   'connection_name': 'Poojitha Emani',
#   'message_sender': 'Vikas Reddy Venkannagari',
#   'message_date': '2025-03-21 22:13:00',
#   'message_text': '',
#   'connection_title': 'clapping hands'},
#  {'message_id': 'messg_78',
#   'conversation_id': 'conv_5',
#   'platform': 'LinkedIn',
#   'connection_name': 'Poojitha Emani',
#   'message_sender': 'Poojitha Emani',
#   'message_date': '2025-03-22 11:04:00',
#   'message_text': 'Coding competition?.. I haven’t done any',
#   'connection_title': 'clapping hands'},
#  {'message_id': 'messg_78',
#   'conversation_id': 'conv_6',
#   'platform': 'LinkedIn',
#   'connection_name': 'Poojitha Emani',
#   'message_sender': 'Vikas Reddy Venkannagari',
#   'message_date': '2025-03-24 10:13:00',
#   'message_text': 'https://jobs.thermofisher.com/global/en/job/R-01306370/Onsite-interview-day-Early-career-Assistant-Scientists?rx_ch=jobpost&rx_job=R-01306370&rx_medium=post&rx_paid=0&rx_r=none&rx_source=linkedin&rx_ts=20250324T124009Z&rx_vp=linkedindirectindex&refId=34jd24&rx_viewer=ee986cf6ba6311ef8713dff482c98560166a8ff4d88c4d77ab0f85b85aeb7a63\n \nHIT evaraina unte share chesey',
#   'connection_title': 'clapping hands'},
#  {'message_id': 'messg_78',
#   'conversation_id': 'conv_7',
#   'platform': 'LinkedIn',
#   'connection_name': 'Poojitha Emani',
#   'message_sender': 'Vikas Reddy Venkannagari',
#   'message_date': '2025-03-26 16:00:00',
#   'message_text': '',
#   'connection_title': 'clapping hands'},
#  {'message_id': 'messg_78',
#   'conversation_id': 'conv_8',
#   'platform': 'LinkedIn',
#   'connection_name': 'Poojitha Emani',
#   'message_sender': 'Vikas Reddy Venkannagari',
#   'message_date': '2025-04-19 10:24:00',
#   'message_text': '',
#   'connection_title': 'clapping hands'},
#  {'message_id': 'messg_78',
#   'conversation_id': 'conv_9',
#   'platform': 'LinkedIn',
#   'connection_name': 'Poojitha Emani',
#   'message_sender': 'Vikas Reddy Venkannagari',
#   'message_date': '2025-04-19 10:51:00',
#   'message_text': '',
#   'connection_title': 'clapping hands'},
#  {'message_id': 'messg_79',
#   'conversation_id': 'conv_0',
#   'platform': 'LinkedIn',
#   'connection_name': 'Supritha kotla',
#   'message_sender': 'Vikas Reddy Venkannagari',
#   'message_date': '2025-04-18 17:26:00',
#   'message_text': 'Hey Supritha, I’m Vikas, a current grad student at UMBC, applying for Software Engineer role at ServiceNow. As a fellow UMBC alum, I’d love your take—would you be open to a referral? I bring over 1.5 years of relevant experience and am happy to share my resume. Thanks!',
#   'connection_title': 'TSE @ServiceNow| Cloud engineer| Information science Graduate, UMBC|Ex Software Engineer-Capgemini'},
#  {'message_id': 'messg_79',
#   'conversation_id': 'conv_1',
#   'platform': 'LinkedIn',
#   'connection_name': 'Supritha kotla',
#   'message_sender': 'Supritha kotla',
#   'message_date': '2025-04-18 17:26:00',
#   'message_text': 'Hi, Vikas Reddy',
#   'connection_title': 'TSE @ServiceNow| Cloud engineer| Information science Graduate, UMBC|Ex Software Engineer-Capgemini'},
#  {'message_id': 'messg_79',
#   'conversation_id': 'conv_2',
#   'platform': 'LinkedIn',
#   'connection_name': 'Supritha kotla',
#   'message_sender': 'Supritha kotla',
#   'message_date': '2025-04-18 17:26:00',
#   'message_text': 'Sure send me the job ID or url',
#   'connection_title': 'TSE @ServiceNow| Cloud engineer| Information science Graduate, UMBC|Ex Software Engineer-Capgemini'},
#  {'message_id': 'messg_79',
#   'conversation_id': 'conv_3',
#   'platform': 'LinkedIn',
#   'connection_name': 'Supritha kotla',
#   'message_sender': 'Supritha kotla',
#   'message_date': '2025-04-18 17:26:00',
#   'message_text': 'I can send you a referral link and you can apply through that',
#   'connection_title': 'TSE @ServiceNow| Cloud engineer| Information science Graduate, UMBC|Ex Software Engineer-Capgemini'},
#  {'message_id': 'messg_79',
#   'conversation_id': 'conv_4',
#   'platform': 'LinkedIn',
#   'connection_name': 'Supritha kotla',
#   'message_sender': 'Vikas Reddy Venkannagari',
#   'message_date': '2025-04-18 17:30:00',
#   'message_text': 'https://careers.servicenow.com/jobs/744000054581185/software-engineer/\n\nIs the role that I am interested in',
#   'connection_title': 'TSE @ServiceNow| Cloud engineer| Information science Graduate, UMBC|Ex Software Engineer-Capgemini'},
#  {'message_id': 'messg_79',
#   'conversation_id': 'conv_5',
#   'platform': 'LinkedIn',
#   'connection_name': 'Supritha kotla',
#   'message_sender': 'Vikas Reddy Venkannagari',
#   'message_date': '2025-04-18 17:30:00',
#   'message_text': 'Thanks for the quick reply ',
#   'connection_title': 'TSE @ServiceNow| Cloud engineer| Information science Graduate, UMBC|Ex Software Engineer-Capgemini'},
#  {'message_id': 'messg_79',
#   'conversation_id': 'conv_6',
#   'platform': 'LinkedIn',
#   'connection_name': 'Supritha kotla',
#   'message_sender': 'Supritha kotla',
#   'message_date': '2025-04-18 19:01:00',
#   'message_text': 'https://smrtr.io/qRCR_',
#   'connection_title': 'TSE @ServiceNow| Cloud engineer| Information science Graduate, UMBC|Ex Software Engineer-Capgemini'},
#  {'message_id': 'messg_79',
#   'conversation_id': 'conv_7',
#   'platform': 'LinkedIn',
#   'connection_name': 'Supritha kotla',
#   'message_sender': 'Vikas Reddy Venkannagari',
#   'message_date': '2025-04-18 19:09:00',
#   'message_text': 'Thanks',
#   'connection_title': 'TSE @ServiceNow| Cloud engineer| Information science Graduate, UMBC|Ex Software Engineer-Capgemini'},
#  {'message_id': 'messg_79',
#   'conversation_id': 'conv_8',
#   'platform': 'LinkedIn',
#   'connection_name': 'Supritha kotla',
#   'message_sender': 'Supritha kotla',
#   'message_date': '2025-04-18 20:12:00',
#   'message_text': "You're welcome",
#   'connection_title': 'TSE @ServiceNow| Cloud engineer| Information science Graduate, UMBC|Ex Software Engineer-Capgemini'},
#  ...]

# %%
# Connect to the PostgreSQL database
connection = psycopg2.connect(
    dbname="messages",
    user="postgres",
    password="password",
    host="localhost",
    port="5432"
)

# Create a cursor object
cursor = connection.cursor()

# Print connection status
print("Connected to the database")
# Out:
# Connected to the database

# %% [markdown]
# ### filter out past messages from being inserted into the postgres

# %%
# Create a set to track unique (message_id, conversation_id) pairs
unique_pairs = set()

# Filter out duplicates
filtered_records = []
for record in combined_records:
    pair = (record['message_id'], record['conversation_id'])
    cursor.execute("""
    SELECT 1 FROM linkedin_messages 
    WHERE message_id = %s AND conversation_id = %s
    """, pair)
    if not cursor.fetchone():
        unique_pairs.add(pair)
        filtered_records.append(record)

print(f"Filtered records count: {len(filtered_records)}")

comb_records = combined_records
combined_records = filtered_records
# Out:
# Filtered records count: 0

# %%
# Preprocess text
def preprocess_text(text):
    return unicodedata.normalize('NFKD', text).encode('ascii', 'ignore').decode('ascii')

# Process the "message_text" field in combined_records
for record in combined_records:
    record["message_text"] = preprocess_text(record["message_text"])

# %% [markdown]
# ### Code to sent the messages into the table

# %%
# 3. Create a new table
cursor.execute("""
CREATE TABLE IF NOT EXISTS linkedin_messages (
  message_id       TEXT,
  conversation_id  TEXT,
  platform         TEXT,
  connection_name  TEXT,
  message_sender   TEXT,
  message_date     TIMESTAMP,
  message_text     TEXT,
  connection_title TEXT,
  PRIMARY KEY (message_id, conversation_id)
);
""")

# 4. Prepare bulk‐insert
sql = """
INSERT INTO linkedin_messages
  (message_id, conversation_id, platform,
   connection_name, message_sender, message_date,
   message_text, connection_title)
VALUES %s
ON CONFLICT DO NOTHING;
"""

values = [
    (
      rec["message_id"],
      rec["conversation_id"],
      rec["platform"],
      rec["connection_name"],
      rec["message_sender"],
      rec["message_date"],        # ISO format → psycopg2 parses to TIMESTAMP
      rec["message_text"],
      rec.get("connection_title")
    )
    for rec in combined_records
]

# 5. Execute and commit
execute_values(cursor, sql, values)
connection.commit()

# %%
# 6. Cleanup
cursor.close()
connection.close()

print(f"Inserted {len(values)} messages (duplicates skipped).")
# Out:
# Inserted 1381 messages (duplicates skipped).

# %% [markdown]
# ### Code to create a 2nd table linkedin_summary, to store the summaries of conversations.

# %%
# Create a new table for the summarized data
cursor.execute("""
CREATE TABLE IF NOT EXISTS linkedin_summary (
    connection_name TEXT,
    message_id      TEXT PRIMARY KEY,
    conversation_id TEXT,
    message_sender  TEXT, 
    message_date    TIMESTAMP
               
);
""")

# %%
message_ids = set()
for index in combined_records:
    message_ids.add(index["message_id"])

print("the total number of records are: ", len(message_ids))

s_records = []

# going through all the records and finding the most recent interaction.
for i in message_ids:
    maxi_convid = -1
    for index in combined_records:
        if i == index["message_id"]:
            conv_id = int(index['conversation_id'].replace("conv_", ""))

            if conv_id > maxi_convid:
                maxi_convid = conv_id
                conversation_id = index["conversation_id"]
                message_sender = index["message_sender"]
                connection_name = index["connection_name"]
                message_date = index["message_date"]
            
    print({"connection_name": connection_name, 
        "message_id": i,
        "conversation_id": maxi_convid,
        "message_sender": message_sender})
    s_records.append({"connection_name" : connection_name, 
                    "message_id" : i,
                    "conversation_id" : conversation_id,
                    "message_sender" : message_sender,
                    "message_date" : message_date})
# Out:
# {'connection_name': 'Chun-Yen Lee', 'message_id': 'messg_67', 'conversation_id': 0, 'message_sender': 'Vikas Reddy Venkannagari'}
# {'connection_name': 'Haixu Leng', 'message_id': 'messg_1', 'conversation_id': 0, 'message_sender': 'Vikas Reddy Venkannagari'}
# {'connection_name': 'Shawn Kerrigan', 'message_id': 'messg_213', 'conversation_id': 0, 'message_sender': 'Vikas Reddy Venkannagari'}
# {'connection_name': 'Sathvika Anugu', 'message_id': 'messg_95', 'conversation_id': 0, 'message_sender': 'Vikas Reddy Venkannagari'}
# {'connection_name': 'Anurag Ganguli', 'message_id': 'messg_212', 'conversation_id': 0, 'message_sender': 'Vikas Reddy Venkannagari'}
# {'connection_name': 'Umme Kulsum', 'message_id': 'messg_41', 'conversation_id': 4, 'message_sender': 'Umme Kulsum'}
# {'connection_name': 'Christopher Rankin', 'message_id': 'messg_59', 'conversation_id': 0, 'message_sender': 'Vikas Reddy Venkannagari'}
# {'connection_name': 'Phanindra Chowdary B', 'message_id': 'messg_171', 'conversation_id': 1, 'message_sender': 'Vikas Reddy Venkannagari'}
# {'connection_name': 'Boris Manakhimov', 'message_id': 'messg_170', 'conversation_id': 0, 'message_sender': 'Vikas Reddy Venkannagari'}
# {'connection_name': 'Shashi Varun Kalimera', 'message_id': 'messg_128', 'conversation_id': 10, 'message_sender': 'Shashi Varun Kalimera'}
# {'connection_name': 'Charles Degliomini', 'message_id': 'messg_167', 'conversation_id': 0, 'message_sender': 'Vikas Reddy Venkannagari'}
# {'connection_name': 'Deborah Oge, MPS’ profile', 'message_id': 'messg_147', 'conversation_id': 0, 'message_sender': 'Vikas Reddy Venkannagari'}
# {'connection_name': 'Nino Hamadeh', 'message_id': 'messg_130', 'conversation_id': 0, 'message_sender': 'Vikas Reddy Venkannagari'}
# {'connection_name': 'Tribhargava Raja Kakarlapudi', 'message_id': 'messg_150', 'conversation_id': 1, 'message_sender': 'Tribhargava Raja Kakarlapudi'}
# {'connection_name': 'Amit Vasudeva', 'message_id': 'messg_138', 'conversation_id': 1, 'message_sender': 'Vikas Reddy Venkannagari'}
# {'connection_name': 'Sina Makhdoomi Kaviri', 'message_id': 'messg_181', 'conversation_id': 0, 'message_sender': 'Vikas Reddy Venkannagari'}
# {'connection_name': 'Grace Henry', 'message_id': 'messg_56', 'conversation_id': 0, 'message_sender': 'Vikas Reddy Venkannagari'}
# {'connection_name': 'Neil Dixit', 'message_id': 'messg_165', 'conversation_id': 0, 'message_sender': 'Vikas Reddy Venkannagari'}
# {'connection_name': 'Vaishnavi Amirapu', 'message_id': 'messg_22', 'conversation_id': 5, 'message_sender': 'Vikas Reddy Venkannagari'}
# {'connection_name': 'Jeet Vayla', 'message_id': 'messg_125', 'conversation_id': 3, 'message_sender': 'Vikas Reddy Venkannagari'}
# {'connection_name': 'Tolu Babalola', 'message_id': 'messg_116', 'conversation_id': 0, 'message_sender': 'Vikas Reddy Venkannagari'}
# {'connection_name': 'Rima Gooden', 'message_id': 'messg_127', 'conversation_id': 0, 'message_sender': 'Vikas Reddy Venkannagari'}
# {'connection_name': 'Shashank Chikara', 'message_id': 'messg_210', 'conversation_id': 0, 'message_sender': 'Vikas Reddy Venkannagari'}
# {'connection_name': 'Krishna Pani', 'message_id': 'messg_62', 'conversation_id': 22, 'message_sender': 'Vikas Reddy Venkannagari'}
# {'connection_name': 'Tapan Kamdar', 'message_id': 'messg_90', 'conversation_id': 6, 'message_sender': 'Tapan Kamdar'}
# {'connection_name': 'Anupam Tiwari', 'message_id': 'messg_89', 'conversation_id': 0, 'message_sender': 'Vikas Reddy Venkannagari'}
# {'connection_name': 'Manish Reddy', 'message_id': 'messg_113', 'conversation_id': 0, 'message_sender': 'Vikas Reddy Venkannagari'}
# {'connection_name': 'Jay Joshi', 'message_id': 'messg_71', 'conversation_id': 4, 'message_sender': 'Jay Joshi'}
# {'connection_name': 'Twinkle Choudhary', 'message_id': 'messg_133', 'conversation_id': 0, 'message_sender': 'Vikas Reddy Venkannagari'}
# {'connection_name': 'Jeffrey Perkins, PHR', 'message_id': 'messg_209', 'conversation_id': 0, 'message_sender': 'Vikas Reddy Venkannagari'}
# {'connection_name': 'Prasad Reddy', 'message_id': 'messg_24', 'conversation_id': 4, 'message_sender': 'Prasad Reddy'}
# {'connection_name': 'Molly Meyers’ profile', 'message_id': 'messg_33', 'conversation_id': 3, 'message_sender': 'Vikas Reddy Venkannagari'}
# {'connection_name': 'Swapnil Joijode', 'message_id': 'messg_187', 'conversation_id': 0, 'message_sender': 'Swapnil Joijode'}
# {'connection_name': 'Shantanu Rangnath Papal', 'message_id': 'messg_174', 'conversation_id': 0, 'message_sender': 'Vikas Reddy Venkannagari'}
# {'connection_name': 'Armando Taveras’ profile', 'message_id': 'messg_8', 'conversation_id': 0, 'message_sender': 'Vikas Reddy Venkannagari'}
# {'connection_name': 'Yuqing Wang, SHRM-CP', 'message_id': 'messg_202', 'conversation_id': 0, 'message_sender': 'Vikas Reddy Venkannagari'}
# {'connection_name': 'Bhavya Shah', 'message_id': 'messg_3', 'conversation_id': 3, 'message_sender': 'Vikas Reddy Venkannagari'}
# {'connection_name': 'Grant Heinonen', 'message_id': 'messg_205', 'conversation_id': 0, 'message_sender': 'Vikas Reddy Venkannagari'}
# {'connection_name': 'Venu Vardhan Reddy Tekula', 'message_id': 'messg_88', 'conversation_id': 13, 'message_sender': 'Venu Vardhan Reddy Tekula'}
# {'connection_name': 'Elton Gbollie', 'message_id': 'messg_7', 'conversation_id': 0, 'message_sender': 'Vikas Reddy Venkannagari'}
# {'connection_name': 'Kapil Gupta', 'message_id': 'messg_141', 'conversation_id': 0, 'message_sender': 'Vikas Reddy Venkannagari'}
# {'connection_name': 'Tanmay Sinha', 'message_id': 'messg_185', 'conversation_id': 8, 'message_sender': 'Tanmay Sinha'}
# {'connection_name': 'Rohit Lokwani', 'message_id': 'messg_21', 'conversation_id': 0, 'message_sender': 'Vikas Reddy Venkannagari'}
# {'connection_name': 'Diwakar Nayak', 'message_id': 'messg_43', 'conversation_id': 0, 'message_sender': 'Vikas Reddy Venkannagari'}
# {'connection_name': 'Imran Sheikh', 'message_id': 'messg_60', 'conversation_id': 0, 'message_sender': 'Vikas Reddy Venkannagari'}
# {'connection_name': 'Pooja Habbu', 'message_id': 'messg_15', 'conversation_id': 0, 'message_sender': 'Vikas Reddy Venkannagari'}
# {'connection_name': 'Kevin Kwan', 'message_id': 'messg_219', 'conversation_id': 0, 'message_sender': 'Vikas Reddy Venkannagari'}
# {'connection_name': 'Collette Curtis’ profile', 'message_id': 'messg_104', 'conversation_id': 0, 'message_sender': 'Vikas Reddy Venkannagari'}
# {'connection_name': 'Karl Hill, CSM, PSM II', 'message_id': 'messg_198', 'conversation_id': 0, 'message_sender': 'Vikas Reddy Venkannagari'}
# {'connection_name': 'Xiaona (Eva) Ou', 'message_id': 'messg_18', 'conversation_id': 0, 'message_sender': 'Vikas Reddy Venkannagari'}
# {'connection_name': 'Sandeep Reddy', 'message_id': 'messg_139', 'conversation_id': 3, 'message_sender': 'Vikas Reddy Venkannagari'}
# {'connection_name': 'Hari Kishore Chaparala', 'message_id': 'messg_61', 'conversation_id': 12, 'message_sender': 'Hari Kishore Chaparala'}
# {'connection_name': 'Haseeb Mahmud', 'message_id': 'messg_197', 'conversation_id': 0, 'message_sender': 'Vikas Reddy Venkannagari'}
# {'connection_name': 'Pragya Sharma', 'message_id': 'messg_36', 'conversation_id': 0, 'message_sender': 'Vikas Reddy Venkannagari'}
# {'connection_name': 'Sydney G.', 'message_id': 'messg_152', 'conversation_id': 0, 'message_sender': 'Vikas Reddy Venkannagari'}
# {'connection_name': 'Surya Teja Yeluri', 'message_id': 'messg_87', 'conversation_id': 0, 'message_sender': 'Vikas Reddy Venkannagari'}
# {'connection_name': 'David Bui', 'message_id': 'messg_222', 'conversation_id': 0, 'message_sender': 'Vikas Reddy Venkannagari'}
# {'connection_name': 'Mattie Dew', 'message_id': 'messg_16', 'conversation_id': 0, 'message_sender': 'Vikas Reddy Venkannagari'}
# {'connection_name': 'Urmi Patel', 'message_id': 'messg_85', 'conversation_id': 0, 'message_sender': 'Vikas Reddy Venkannagari'}
# {'connection_name': 'Ashwin Jayaraman', 'message_id': 'messg_68', 'conversation_id': 2, 'message_sender': 'Vikas Reddy Venkannagari'}
# {'connection_name': 'Emma Proctor', 'message_id': 'messg_226', 'conversation_id': 0, 'message_sender': 'Vikas Reddy Venkannagari'}
# {'connection_name': 'Anil Vaddi', 'message_id': 'messg_101', 'conversation_id': 0, 'message_sender': 'Vikas Reddy Venkannagari'}
# {'connection_name': 'Michelle Bruce', 'message_id': 'messg_27', 'conversation_id': 4, 'message_sender': 'Vikas Reddy Venkannagari'}
# {'connection_name': 'Manujith Prakash', 'message_id': 'messg_75', 'conversation_id': 11, 'message_sender': 'Vikas Reddy Venkannagari'}
# {'connection_name': 'Vinay Kota', 'message_id': 'messg_145', 'conversation_id': 1, 'message_sender': 'Vikas Reddy Venkannagari'}
# {'connection_name': 'Moroti Oyeyemi', 'message_id': 'messg_91', 'conversation_id': 5, 'message_sender': 'Vikas Reddy Venkannagari'}
# {'connection_name': 'Joseph Paparella', 'message_id': 'messg_161', 'conversation_id': 0, 'message_sender': 'Vikas Reddy Venkannagari'}
# {'connection_name': 'Sruthi Sundharram', 'message_id': 'messg_175', 'conversation_id': 4, 'message_sender': 'Sruthi Sundharram'}
# {'connection_name': 'Mengrui Yuan', 'message_id': 'messg_225', 'conversation_id': 1, 'message_sender': 'Vikas Reddy Venkannagari'}
# {'connection_name': 'Laurine Karnley', 'message_id': 'messg_83', 'conversation_id': 8, 'message_sender': 'Vikas Reddy Venkannagari'}
# {'connection_name': 'H M Sajjad Hossain', 'message_id': 'messg_124', 'conversation_id': 3, 'message_sender': 'H M Sajjad Hossain'}
# {'connection_name': 'Tyler Jones’ profile', 'message_id': 'messg_151', 'conversation_id': 0, 'message_sender': 'Vikas Reddy Venkannagari'}
# {'connection_name': 'Henry Murdock', 'message_id': 'messg_63', 'conversation_id': 0, 'message_sender': 'Vikas Reddy Venkannagari'}
# {'connection_name': 'Aravind Bolloli', 'message_id': 'messg_102', 'conversation_id': 0, 'message_sender': 'Vikas Reddy Venkannagari'}
# {'connection_name': 'Himanshi Arora', 'message_id': 'messg_13', 'conversation_id': 0, 'message_sender': 'Vikas Reddy Venkannagari'}
# {'connection_name': 'Kajal Shah', 'message_id': 'messg_38', 'conversation_id': 0, 'message_sender': 'Vikas Reddy Venkannagari'}
# {'connection_name': 'Maria Goretti Rivera', 'message_id': 'messg_203', 'conversation_id': 8, 'message_sender': 'Vikas Reddy Venkannagari'}
# {'connection_name': 'David Desharnais’ profile', 'message_id': 'messg_160', 'conversation_id': 0, 'message_sender': 'Vikas Reddy Venkannagari'}
# {'connection_name': 'Tahsina Tarannum Mustafa', 'message_id': 'messg_169', 'conversation_id': 2, 'message_sender': 'Vikas Reddy Venkannagari'}
# {'connection_name': 'Vincent Reid', 'message_id': 'messg_10', 'conversation_id': 0, 'message_sender': 'Vikas Reddy Venkannagari'}
# {'connection_name': 'Sriram Kumar Toram', 'message_id': 'messg_142', 'conversation_id': 0, 'message_sender': 'Vikas Reddy Venkannagari'}
# {'connection_name': 'Akash Raju', 'message_id': 'messg_159', 'conversation_id': 0, 'message_sender': 'Vikas Reddy Venkannagari'}
# {'connection_name': 'Priyanshu Arora', 'message_id': 'messg_100', 'conversation_id': 3, 'message_sender': 'Priyanshu Arora'}
# {'connection_name': 'Pratham Reddy', 'message_id': 'messg_72', 'conversation_id': 5, 'message_sender': 'Vikas Reddy Venkannagari'}
# {'connection_name': 'Dennis White', 'message_id': 'messg_173', 'conversation_id': 0, 'message_sender': 'Vikas Reddy Venkannagari'}
# {'connection_name': 'Sri Teja Vure', 'message_id': 'messg_23', 'conversation_id': 12, 'message_sender': 'Vikas Reddy Venkannagari'}
# {'connection_name': 'Apurv Pentewar', 'message_id': 'messg_121', 'conversation_id': 10, 'message_sender': 'Apurv Pentewar'}
# {'connection_name': 'Lexie Kronforst', 'message_id': 'messg_53', 'conversation_id': 0, 'message_sender': 'Vikas Reddy Venkannagari'}
# {'connection_name': 'Joshua Welck', 'message_id': 'messg_28', 'conversation_id': 2, 'message_sender': 'Vikas Reddy Venkannagari'}
# {'connection_name': 'Sambit Sahu', 'message_id': 'messg_143', 'conversation_id': 0, 'message_sender': 'Vikas Reddy Venkannagari'}
# {'connection_name': 'Abhinav Varma V', 'message_id': 'messg_176', 'conversation_id': 13, 'message_sender': 'Abhinav Varma V'}
# {'connection_name': 'Sai Dwibhashyam', 'message_id': 'messg_135', 'conversation_id': 0, 'message_sender': 'Vikas Reddy Venkannagari'}
# {'connection_name': 'Ashwin Vishwanathan', 'message_id': 'messg_189', 'conversation_id': 0, 'message_sender': 'Ashwin Vishwanathan'}
# {'connection_name': 'Krish Gupta', 'message_id': 'messg_66', 'conversation_id': 0, 'message_sender': 'Vikas Reddy Venkannagari'}
# {'connection_name': 'Saurav Pahadia', 'message_id': 'messg_218', 'conversation_id': 0, 'message_sender': 'Vikas Reddy Venkannagari'}
# {'connection_name': 'Trideep Rath', 'message_id': 'messg_208', 'conversation_id': 0, 'message_sender': 'Vikas Reddy Venkannagari'}
# {'connection_name': 'Maheshbabu Davuluri', 'message_id': 'messg_81', 'conversation_id': 2, 'message_sender': 'Vikas Reddy Venkannagari'}
# {'connection_name': 'Anubhav Paras’ profile', 'message_id': 'messg_220', 'conversation_id': 0, 'message_sender': 'Vikas Reddy Venkannagari'}
# {'connection_name': 'Rishabh Bassi', 'message_id': 'messg_9', 'conversation_id': 0, 'message_sender': 'Vikas Reddy Venkannagari'}
# {'connection_name': 'Seema Mujawdiya', 'message_id': 'messg_134', 'conversation_id': 0, 'message_sender': 'Vikas Reddy Venkannagari'}
# {'connection_name': 'Saritha Reddy Loka', 'message_id': 'messg_34', 'conversation_id': 0, 'message_sender': 'Vikas Reddy Venkannagari'}
# {'connection_name': 'Akash Narang', 'message_id': 'messg_86', 'conversation_id': 0, 'message_sender': 'Vikas Reddy Venkannagari'}
# {'connection_name': 'James Nichols’ profile', 'message_id': 'messg_118', 'conversation_id': 7, 'message_sender': 'Vikas Reddy Venkannagari'}
# {'connection_name': 'Filip Dabek', 'message_id': 'messg_126', 'conversation_id': 0, 'message_sender': 'Vikas Reddy Venkannagari'}
# {'connection_name': 'Ashish Shugani', 'message_id': 'messg_109', 'conversation_id': 2, 'message_sender': 'Vikas Reddy Venkannagari'}
# {'connection_name': 'Heet Detroja', 'message_id': 'messg_47', 'conversation_id': 0, 'message_sender': 'Vikas Reddy Venkannagari'}
# {'connection_name': 'Yeswanth sai Yerramasu', 'message_id': 'messg_105', 'conversation_id': 1, 'message_sender': 'Vikas Reddy Venkannagari'}
# {'connection_name': 'Alexander Lechner, MSc BSc', 'message_id': 'messg_183', 'conversation_id': 2, 'message_sender': 'Alexander Lechner, MSc BSc'}
# {'connection_name': 'Prashant Verma, PhD', 'message_id': 'messg_31', 'conversation_id': 0, 'message_sender': 'Vikas Reddy Venkannagari'}
# {'connection_name': 'Javier Lopez', 'message_id': 'messg_207', 'conversation_id': 0, 'message_sender': 'Vikas Reddy Venkannagari'}
# {'connection_name': 'uday kumar', 'message_id': 'messg_94', 'conversation_id': 0, 'message_sender': 'Vikas Reddy Venkannagari'}
# {'connection_name': 'Isaac-David Rodriguez', 'message_id': 'messg_217', 'conversation_id': 0, 'message_sender': 'Vikas Reddy Venkannagari'}
# {'connection_name': 'Devi Manaswi Kallam', 'message_id': 'messg_17', 'conversation_id': 0, 'message_sender': 'Vikas Reddy Venkannagari'}
# {'connection_name': 'Akhil Sai', 'message_id': 'messg_40', 'conversation_id': 0, 'message_sender': 'Vikas Reddy Venkannagari'}
# {'connection_name': 'Saketh Reddy', 'message_id': 'messg_107', 'conversation_id': 0, 'message_sender': 'Vikas Reddy Venkannagari'}
# {'connection_name': 'Sameer Kibey', 'message_id': 'messg_2', 'conversation_id': 15, 'message_sender': 'Sameer Kibey'}
# {'connection_name': 'Vikash Srivastava', 'message_id': 'messg_163', 'conversation_id': 0, 'message_sender': 'Vikas Reddy Venkannagari'}
# {'connection_name': 'Nancy Huynh', 'message_id': 'messg_199', 'conversation_id': 0, 'message_sender': 'Vikas Reddy Venkannagari'}
# {'connection_name': 'Lauren Salustro', 'message_id': 'messg_191', 'conversation_id': 0, 'message_sender': 'Vikas Reddy Venkannagari'}
# {'connection_name': 'Namruth Thimmapuram', 'message_id': 'messg_0', 'conversation_id': 23, 'message_sender': 'Namruth Thimmapuram'}
# {'connection_name': 'Shikhar Singh', 'message_id': 'messg_49', 'conversation_id': 2, 'message_sender': 'Vikas Reddy Venkannagari'}
# {'connection_name': 'Julia Fetsek', 'message_id': 'messg_155', 'conversation_id': 0, 'message_sender': 'Vikas Reddy Venkannagari'}
# {'connection_name': 'Cheryl Diakun', 'message_id': 'messg_193', 'conversation_id': 0, 'message_sender': 'Vikas Reddy Venkannagari'}
# {'connection_name': 'Janielle Rodriguez', 'message_id': 'messg_204', 'conversation_id': 0, 'message_sender': 'Vikas Reddy Venkannagari'}
# {'connection_name': 'Anusha Pugazhendhi', 'message_id': 'messg_82', 'conversation_id': 3, 'message_sender': 'Vikas Reddy Venkannagari'}
# {'connection_name': 'George DeBakey', 'message_id': 'messg_168', 'conversation_id': 0, 'message_sender': 'Vikas Reddy Venkannagari'}
# {'connection_name': 'Anand Y', 'message_id': 'messg_196', 'conversation_id': 10, 'message_sender': 'Anand Y'}
# {'connection_name': 'Harish Reddy', 'message_id': 'messg_146', 'conversation_id': 3, 'message_sender': 'Vikas Reddy Venkannagari'}
# {'connection_name': 'Mingxiu Du', 'message_id': 'messg_172', 'conversation_id': 0, 'message_sender': 'Vikas Reddy Venkannagari'}
# {'connection_name': 'Aman Bhala', 'message_id': 'messg_112', 'conversation_id': 2, 'message_sender': 'Vikas Reddy Venkannagari'}
# {'connection_name': 'Eric Najdek', 'message_id': 'messg_55', 'conversation_id': 0, 'message_sender': 'Vikas Reddy Venkannagari'}
# {'connection_name': 'Andrew Lihn', 'message_id': 'messg_25', 'conversation_id': 5, 'message_sender': 'Vikas Reddy Venkannagari'}
# {'connection_name': 'Murali Marupudi', 'message_id': 'messg_96', 'conversation_id': 0, 'message_sender': 'Vikas Reddy Venkannagari'}
# {'connection_name': 'Anusha Battu', 'message_id': 'messg_140', 'conversation_id': 0, 'message_sender': 'Vikas Reddy Venkannagari'}
# {'connection_name': 'Abdul Waseh', 'message_id': 'messg_39', 'conversation_id': 0, 'message_sender': 'Vikas Reddy Venkannagari'}
# {'connection_name': 'Nino Hamadeh', 'message_id': 'messg_149', 'conversation_id': 0, 'message_sender': 'Vikas Reddy Venkannagari'}
# {'connection_name': 'Reymark Renigen', 'message_id': 'messg_223', 'conversation_id': 1, 'message_sender': 'Vikas Reddy Venkannagari'}
# {'connection_name': 'Franco Bulaon', 'message_id': 'messg_136', 'conversation_id': 0, 'message_sender': 'Vikas Reddy Venkannagari'}
# {'connection_name': 'Mark Susol', 'message_id': 'messg_106', 'conversation_id': 4, 'message_sender': 'Vikas Reddy Venkannagari'}
# {'connection_name': 'Siddharth B', 'message_id': 'messg_190', 'conversation_id': 0, 'message_sender': 'Siddharth B'}
# {'connection_name': 'Shvetan Katta', 'message_id': 'messg_77', 'conversation_id': 0, 'message_sender': 'Vikas Reddy Venkannagari'}
# {'connection_name': 'Salluri Sumanth', 'message_id': 'messg_188', 'conversation_id': 6, 'message_sender': 'Salluri Sumanth'}
# {'connection_name': 'Chris White', 'message_id': 'messg_111', 'conversation_id': 0, 'message_sender': 'Vikas Reddy Venkannagari'}
# {'connection_name': 'Scott Painter', 'message_id': 'messg_157', 'conversation_id': 0, 'message_sender': 'Vikas Reddy Venkannagari'}
# {'connection_name': 'Bianca Colombari R.', 'message_id': 'messg_120', 'conversation_id': 0, 'message_sender': 'Bianca Colombari R.'}
# {'connection_name': 'Jeevan Sirivella', 'message_id': 'messg_180', 'conversation_id': 2, 'message_sender': 'Jeevan Sirivella'}
# {'connection_name': 'Daniel Adjei', 'message_id': 'messg_99', 'conversation_id': 8, 'message_sender': 'Vikas Reddy Venkannagari'}
# {'connection_name': 'Marilyn Maggio', 'message_id': 'messg_69', 'conversation_id': 0, 'message_sender': 'Vikas Reddy Venkannagari'}
# {'connection_name': 'Poojitha Emani', 'message_id': 'messg_78', 'conversation_id': 9, 'message_sender': 'Vikas Reddy Venkannagari'}
# {'connection_name': 'Sindhu Sree Aita', 'message_id': 'messg_73', 'conversation_id': 0, 'message_sender': 'Vikas Reddy Venkannagari'}
# {'connection_name': 'Ramana Vinjamuri', 'message_id': 'messg_182', 'conversation_id': 2, 'message_sender': 'Vikas Reddy Venkannagari'}
# {'connection_name': 'Maddipati Venkata Akarsh', 'message_id': 'messg_117', 'conversation_id': 2, 'message_sender': 'Vikas Reddy Venkannagari'}
# {'connection_name': 'Prachi Rahurkar', 'message_id': 'messg_148', 'conversation_id': 0, 'message_sender': 'Vikas Reddy Venkannagari'}
# {'connection_name': 'Christian Allen', 'message_id': 'messg_30', 'conversation_id': 0, 'message_sender': 'Vikas Reddy Venkannagari'}
# {'connection_name': 'Sadhana Reddy Mudhireddy', 'message_id': 'messg_45', 'conversation_id': 15, 'message_sender': 'Vikas Reddy Venkannagari'}
# {'connection_name': 'Yatish Joshi', 'message_id': 'messg_98', 'conversation_id': 11, 'message_sender': 'Vikas Reddy Venkannagari'}
# {'connection_name': 'Zachary Wachtel', 'message_id': 'messg_119', 'conversation_id': 0, 'message_sender': 'Vikas Reddy Venkannagari'}
# {'connection_name': 'Betsir Zemen, Ph.D.', 'message_id': 'messg_122', 'conversation_id': 11, 'message_sender': 'Betsir Zemen, Ph.D.'}
# {'connection_name': 'Stephen Eliazer', 'message_id': 'messg_224', 'conversation_id': 1, 'message_sender': 'Vikas Reddy Venkannagari'}
# {'connection_name': 'Vaishali Sharma', 'message_id': 'messg_137', 'conversation_id': 1, 'message_sender': 'Vikas Reddy Venkannagari'}
# {'connection_name': 'Mahesh Goudar', 'message_id': 'messg_192', 'conversation_id': 0, 'message_sender': 'Mahesh Goudar'}
# {'connection_name': 'Gaurav Patnashetty', 'message_id': 'messg_221', 'conversation_id': 2, 'message_sender': 'Vikas Reddy Venkannagari'}
# {'connection_name': 'Siddartha Kodaboina', 'message_id': 'messg_186', 'conversation_id': 1, 'message_sender': 'Vikas Reddy Venkannagari'}
# {'connection_name': 'Suraj Nammi', 'message_id': 'messg_80', 'conversation_id': 0, 'message_sender': 'Vikas Reddy Venkannagari'}
# {'connection_name': 'Jiahao Xu', 'message_id': 'messg_42', 'conversation_id': 0, 'message_sender': 'Vikas Reddy Venkannagari'}
# {'connection_name': 'Bob Marshall', 'message_id': 'messg_214', 'conversation_id': 0, 'message_sender': 'Vikas Reddy Venkannagari'}
# {'connection_name': 'Rehman Ali Shaik', 'message_id': 'messg_48', 'conversation_id': 2, 'message_sender': 'Vikas Reddy Venkannagari'}
# {'connection_name': 'Chad Edwards’ profile', 'message_id': 'messg_156', 'conversation_id': 0, 'message_sender': 'Vikas Reddy Venkannagari'}
# {'connection_name': 'Lakshmi Muralidharan', 'message_id': 'messg_50', 'conversation_id': 0, 'message_sender': 'Vikas Reddy Venkannagari'}
# {'connection_name': 'Gregory Watson', 'message_id': 'messg_70', 'conversation_id': 0, 'message_sender': 'Vikas Reddy Venkannagari'}
# {'connection_name': 'Amanda Araneda', 'message_id': 'messg_44', 'conversation_id': 0, 'message_sender': 'Vikas Reddy Venkannagari'}
# {'connection_name': 'Max Poole', 'message_id': 'messg_103', 'conversation_id': 1, 'message_sender': 'Max Poole'}
# {'connection_name': 'Mathea Durica', 'message_id': 'messg_215', 'conversation_id': 0, 'message_sender': 'Vikas Reddy Venkannagari'}
# {'connection_name': 'Kristina Callahan', 'message_id': 'messg_74', 'conversation_id': 0, 'message_sender': 'Vikas Reddy Venkannagari'}
# {'connection_name': 'Anupama Balotra', 'message_id': 'messg_129', 'conversation_id': 0, 'message_sender': 'Vikas Reddy Venkannagari'}
# {'connection_name': 'Pooja Habbu', 'message_id': 'messg_14', 'conversation_id': 2, 'message_sender': 'Vikas Reddy Venkannagari'}
# {'connection_name': 'Yijie Huang', 'message_id': 'messg_35', 'conversation_id': 0, 'message_sender': 'Vikas Reddy Venkannagari'}
# {'connection_name': 'Bhawneet Singh', 'message_id': 'messg_57', 'conversation_id': 12, 'message_sender': 'Bhawneet Singh'}
# {'connection_name': 'Prajit Das’ profile', 'message_id': 'messg_110', 'conversation_id': 0, 'message_sender': 'Vikas Reddy Venkannagari'}
# {'connection_name': 'Prerit Jain', 'message_id': 'messg_93', 'conversation_id': 3, 'message_sender': 'Vikas Reddy Venkannagari'}
# {'connection_name': 'Mihin Sumaria', 'message_id': 'messg_184', 'conversation_id': 0, 'message_sender': 'Vikas Reddy Venkannagari'}
# {'connection_name': 'Anjani Lingamallu', 'message_id': 'messg_92', 'conversation_id': 3, 'message_sender': 'Anjani Lingamallu'}
# {'connection_name': 'Mahesh Goudar', 'message_id': 'messg_195', 'conversation_id': 0, 'message_sender': 'Mahesh Goudar'}
# {'connection_name': 'Sara Marschall', 'message_id': 'messg_166', 'conversation_id': 0, 'message_sender': 'Vikas Reddy Venkannagari'}
# {'connection_name': 'Christie Orlova', 'message_id': 'messg_154', 'conversation_id': 0, 'message_sender': 'Vikas Reddy Venkannagari'}
# {'connection_name': 'Tarun Khurana', 'message_id': 'messg_32', 'conversation_id': 7, 'message_sender': 'Tarun Khurana'}
# {'connection_name': 'sachin sharma', 'message_id': 'messg_76', 'conversation_id': 0, 'message_sender': 'Vikas Reddy Venkannagari'}
# {'connection_name': 'Parth Purani', 'message_id': 'messg_84', 'conversation_id': 11, 'message_sender': 'Vikas Reddy Venkannagari'}
# {'connection_name': 'Harsh Dankhara', 'message_id': 'messg_97', 'conversation_id': 2, 'message_sender': 'Vikas Reddy Venkannagari'}
# {'connection_name': 'Audrey Park', 'message_id': 'messg_54', 'conversation_id': 0, 'message_sender': 'Vikas Reddy Venkannagari'}
# {'connection_name': 'Supritha kotla', 'message_id': 'messg_79', 'conversation_id': 8, 'message_sender': 'Supritha kotla'}
# {'connection_name': 'Asmita Badwar', 'message_id': 'messg_46', 'conversation_id': 0, 'message_sender': 'Vikas Reddy Venkannagari'}
# {'connection_name': 'Akil Savvas’ profile', 'message_id': 'messg_11', 'conversation_id': 0, 'message_sender': 'Vikas Reddy Venkannagari'}
# {'connection_name': 'Justin Hilleary', 'message_id': 'messg_5', 'conversation_id': 0, 'message_sender': 'Vikas Reddy Venkannagari'}
# {'connection_name': 'Laura Mammen', 'message_id': 'messg_162', 'conversation_id': 0, 'message_sender': 'Vikas Reddy Venkannagari'}
# {'connection_name': 'Ronak Patil', 'message_id': 'messg_26', 'conversation_id': 6, 'message_sender': 'Ronak Patil'}
# {'connection_name': 'Samad Jafar-Zanjani', 'message_id': 'messg_64', 'conversation_id': 0, 'message_sender': 'Vikas Reddy Venkannagari'}
# {'connection_name': 'Oum Venkata Narayana Goud Mogadampally', 'message_id': 'messg_164', 'conversation_id': 2, 'message_sender': 'Vikas Reddy Venkannagari'}
# {'connection_name': 'Phil Henry', 'message_id': 'messg_194', 'conversation_id': 5, 'message_sender': 'Vikas Reddy Venkannagari'}
# {'connection_name': 'Carol Lee', 'message_id': 'messg_216', 'conversation_id': 0, 'message_sender': 'Vikas Reddy Venkannagari'}
# {'connection_name': 'Chinedu Okeke', 'message_id': 'messg_131', 'conversation_id': 0, 'message_sender': 'Vikas Reddy Venkannagari'}
# {'connection_name': 'Joel Kronander', 'message_id': 'messg_29', 'conversation_id': 0, 'message_sender': 'Vikas Reddy Venkannagari'}
# {'connection_name': 'Jessica Brabant', 'message_id': 'messg_58', 'conversation_id': 0, 'message_sender': 'Vikas Reddy Venkannagari'}
# {'connection_name': 'Morgan Bass’ profile', 'message_id': 'messg_153', 'conversation_id': 0, 'message_sender': 'Vikas Reddy Venkannagari'}
# {'connection_name': 'Steven Yu', 'message_id': 'messg_51', 'conversation_id': 0, 'message_sender': 'Vikas Reddy Venkannagari'}
# {'connection_name': 'Pavani M', 'message_id': 'messg_227', 'conversation_id': 6, 'message_sender': 'Pavani M'}
# {'connection_name': 'Joe Aurelio', 'message_id': 'messg_115', 'conversation_id': 12, 'message_sender': 'Joe Aurelio'}
# {'connection_name': 'Anmol Dash', 'message_id': 'messg_144', 'conversation_id': 0, 'message_sender': 'Vikas Reddy Venkannagari'}
# {'connection_name': 'Aishvarya Singh', 'message_id': 'messg_6', 'conversation_id': 0, 'message_sender': 'Vikas Reddy Venkannagari'}
# {'connection_name': 'Lang-An (Ryan) Tsai', 'message_id': 'messg_37', 'conversation_id': 0, 'message_sender': 'Vikas Reddy Venkannagari'}
# {'connection_name': 'Niha G', 'message_id': 'messg_108', 'conversation_id': 0, 'message_sender': 'Vikas Reddy Venkannagari'}
# {'connection_name': 'Tolu Atanda', 'message_id': 'messg_4', 'conversation_id': 9, 'message_sender': 'Vikas Reddy Venkannagari'}
# {'connection_name': 'Sanjay Rangan', 'message_id': 'messg_201', 'conversation_id': 0, 'message_sender': 'Vikas Reddy Venkannagari'}
# {'connection_name': 'Kyra Morgan', 'message_id': 'messg_206', 'conversation_id': 0, 'message_sender': 'Vikas Reddy Venkannagari'}
# {'connection_name': 'Deborah Rheem', 'message_id': 'messg_52', 'conversation_id': 0, 'message_sender': 'Vikas Reddy Venkannagari'}
# {'connection_name': 'Kent Dang', 'message_id': 'messg_65', 'conversation_id': 5, 'message_sender': 'Vikas Reddy Venkannagari'}
# {'connection_name': 'John Dennis’ profile', 'message_id': 'messg_211', 'conversation_id': 2, 'message_sender': 'Vikas Reddy Venkannagari'}
# {'connection_name': 'Bonakolluru Ajay Kumar', 'message_id': 'messg_12', 'conversation_id': 0, 'message_sender': 'Vikas Reddy Venkannagari'}
# {'connection_name': 'Britney Maddern', 'message_id': 'messg_200', 'conversation_id': 0, 'message_sender': 'Vikas Reddy Venkannagari'}
# {'connection_name': 'Lisa Reshaur', 'message_id': 'messg_132', 'conversation_id': 0, 'message_sender': 'Vikas Reddy Venkannagari'}
# {'connection_name': 'Manas Goutham', 'message_id': 'messg_123', 'conversation_id': 1, 'message_sender': 'Vikas Reddy Venkannagari'}
# {'connection_name': 'Eric Kim', 'message_id': 'messg_114', 'conversation_id': 0, 'message_sender': 'Vikas Reddy Venkannagari'}
# {'connection_name': 'Noah Fram-Schwartz', 'message_id': 'messg_158', 'conversation_id': 0, 'message_sender': 'Vikas Reddy Venkannagari'}

# %%
summary_sql = """
INSERT INTO linkedin_summary
  (connection_name, message_id, conversation_id, message_sender, message_date)
VALUES %s
ON CONFLICT DO NOTHING;
"""

# Prepare the values for insertion
values = [
  (
    rec["connection_name"],
    rec["message_id"],
    rec["conversation_id"],
    rec["message_sender"],
    rec["message_date"]
  )
  for rec in s_records
]

# Execute and commit
execute_values(cursor, summary_sql, values)
connection.commit()

# 6. Cleanup
# cursor.close()
# connection.close()

# %% [markdown]
# ## Part 2 : Generating Summary

# %% [markdown]
# ### generate the summaries for all the conversations

# %%
def get_conversation_by_message_id(conn, message_id):
    """Retrieve all messages for a given message_id and format as a conversation."""
    try:
        cursor = conn.cursor()
        cursor.execute("""
            SELECT message_sender, message_date, message_text, connection_title
            FROM linkedin_messages
            WHERE message_id = %s
            ORDER BY message_date ASC
        """, (message_id,))
        rows = cursor.fetchall()
        cursor.close()
        
        # Format conversation as a string
        conversation = ""
        for row in rows:
            sender, date, text, title = row
            conversation += f"{sender} ({date}): {text}\n"
        return conversation.strip(), title
    except Exception as e:
        print(f"Error fetching conversation for message_id {message_id}: {e}")
        return ""

# %%
from dotenv import load_dotenv
import os
from langchain.chat_models import ChatOpenAI

# Load environment variables from .env file
load_dotenv()

# Get the SUMMARIES_OPENAI variable
api_key_openai = os.getenv("SUMMARIES_OPENAI")

# Initialize OpenAI model via LangChain
llm = ChatOpenAI(
    openai_api_key=api_key_openai,
    temperature=0.3,
    max_tokens=1024,
    model="gpt-3.5-turbo",
    verbose=True,
)

message_ids = set()
for index in combined_records:
    message_ids.add(index["message_id"])

print("the total number of records are: ", len(message_ids))
# Out:
# the total number of records are:  223

# %%
from langchain_community.llms import Ollama
from langchain.prompts import PromptTemplate
from langchain.chains import LLMChain
from langchain_ollama import ChatOllama


# Define prompt template for summarization
prompt_template = PromptTemplate(
    input_variables=["conversation"],
    template="""You are a helpful assistant that summarizes LinkedIn chat conversations.

        Summarize the conversation below in 3–5 sentences. Focus on:
        - Who I messaged and their role/company
        - My intent (e.g., asking for a referral, meeting, or recruiter intro)
        - Their response and any follow-up actions
        - Whether a resume, project, or portfolio was shared
        - Outcome or current status (e.g., they agreed, ignored, redirected)

        The summary should help me remember this conversation later, without rereading it.
        \n\n{conversation}"""
)

# Create LLM chain for summarization
summary_chain = LLMChain(llm=llm, prompt=prompt_template)

def generate_summary(conversation):
    """Generate a summary for the given conversation using LangChain and Ollama."""
    try:
        summary = summary_chain.run(conversation=conversation)
        return summary.strip()
    except Exception as e:
        print(f"Error generating summary: {e}")
        return "Summary generation failed."



# Define a new prompt template for extracting the company name in JSON format
json_prompt_template = PromptTemplate(
    input_variables=["conversation", "title"],
    template="""You are an assistant that extracts the company name from LinkedIn chat conversations.

        Based on the conversation and title provided below, identify the company name. If the company cannot be determined, return "None".

        Output the result in JSON format with the following structure:
        {{
            "company_name": "<company_name or None>"
        }}

        Conversation: {conversation}
        Title: {title}
    """
)

# Create a new LLM chain for extracting the company name
json_chain = LLMChain(llm=llm, prompt=json_prompt_template)

def extract_company_name(conversation, title):
    """Extract the company name from the conversation and title using LangChain."""
    try:
        result = json_chain.run(conversation=conversation, title=title)
        return result.strip()
    except Exception as e:
        print(f"Error extracting company name: {e}")
        return '{"company_name": "None"}'

# %%
summaries = []
from tqdm import tqdm  

for message_id in tqdm(message_ids):
    # Retrieve rows with the same message_id from the database
    
    conversation, title = get_conversation_by_message_id(connection, message_id)
    
    # Generate summary
    summary = generate_summary(conversation)

    company = extract_company_name(conversation, title)
    clean = company.replace('```json\n', '').replace('\n```', '')
    data = json.loads(clean)

    # Store summary with metadata
    summaries.append({
        "message_id": message_id,
        "conversation": conversation,
        "summary": summary,
        "company": data["company_name"]
    })
# Out:
# 100%|██████████| 223/223 [05:00<00:00,  1.35s/it]

# %%
summaries
# Out:
# [{'message_id': 'messg_82',
#   'conversation': 'Vikas Reddy Venkannagari (2025-04-15 19:58:00): Hey Anusha, Im Vikas, a current grad student at UMBC, applying for Data Analyst role at Concentrix. Id love your takewould you be open to a referral? I bring over 1.5 years of relevant experience and am happy to share my resume. Thanks!\nAnusha Pugazhendhi (2025-04-15 19:59:00): Hi Vikas, yes sure. Please give me your full name, address and resume\nAnusha Pugazhendhi (2025-04-15 19:59:00): Also send the job link here \nVikas Reddy Venkannagari (2025-04-18 14:09:00): Sorry for the late reply Anusha, and thanks for offering me a referral. The role that I was interested was closed, and all the other roles seems not be aligned for new grads, I will let you know if I find a good fit.',
#   'summary': "I messaged Anusha Pugazhendhi, who works at Concentrix, asking for a referral for a Data Analyst role. Anusha agreed to provide a referral and requested my full name, address, resume, and the job link. I shared the required information, but later informed Anusha that the role I was interested in had closed, and other roles didn't seem suitable for new grads. I mentioned that I would reach out if I found a better fit in the future. No further actions were mentioned, and the current status is that I will keep Anusha updated on any relevant opportunities.",
#   'company': 'Concentrix'},
#  {'message_id': 'messg_28',
#   'conversation': "Vikas Reddy Venkannagari (2025-04-30 09:06:00): Hey Joshua, Im Vikas, a current grad student at UMBC, applying for Algorithm Engineer role at KLA. As a fellow UMBC alum, Id love your takewould you be open to a referral? I bring over 1.5 years of relevant experience and am happy to share my resume. Thanks!\nJoshua Welck (2025-04-30 09:09:00): Hi Vikas,\n\nUnfortunately I don't think I'll be a good referral to you. I'm leaving KLA in the next few weeks as the amount of travel for a field service engineer is a bit overwhelming. Best of luck to you in your future endeavors.\n\nJosh\nVikas Reddy Venkannagari (2025-04-30 10:55:00): Thanks Joshua for responding, all the very best in your next role.",
#   'summary': 'I messaged Joshua Welck, a field service engineer at KLA, seeking a referral for an Algorithm Engineer role. Joshua declined the referral as he was leaving KLA soon due to travel demands. I thanked Joshua for his response and wished him luck in his future endeavors. No resume was shared, and the outcome was Joshua declining the referral.',
#   'company': 'KLA'},
#  {'message_id': 'messg_68',
#   'conversation': 'Vikas Reddy Venkannagari (2025-04-23 13:26:00): Hey Ashwin, Im Vikas, a current grad student at UMBC, applying for Algorithm Engineer role at KLA. Id love your takewould you be open to a referral? I bring over 1.5 years of relevant experience and am happy to share my resume. Thanks!\nAshwin Jayaraman (2025-04-23 13:26:00): Sure, send me your resume and job id at Ashwin.jayaraman@kla.com\nVikas Reddy Venkannagari (2025-04-23 13:27:00): thanks for the quick reply, sending in my resume',
#   'summary': 'I messaged Ashwin Jayaraman from KLA about a referral for an Algorithm Engineer role. Ashwin agreed to the referral and requested my resume and the job ID, which I promptly shared. Currently waiting for further updates on the referral process.',
#   'company': 'KLA'},
#  {'message_id': 'messg_92',
#   'conversation': 'Vikas Reddy Venkannagari (2025-04-14 12:14:00): Hey Anjani, Im Vikas, a current grad student at UMBC, applying for AI Engineer role at Cisco. As a fellow UMBC alum, Id love your takewould you be open to a referral? I bring over 1.5 years of relevant experience and am happy to share my resume. Thanks!\nAnjani Lingamallu (2025-04-14 12:14:00): Hello Vikas,\n\nGlad to hear from you. \nUnfortunately, I might not be able to help you with this since Im on a contract role\nPlease let me know if there is any way I can help you.\n\nRegards,\nAnjani.\nVikas Reddy Venkannagari (2025-04-14 12:41:00): Hello Anjani, Thanks for letting me know !\nAnjani Lingamallu (2025-04-14 13:00:00):',
#   'summary': 'Anjani Lingamallu, who is on a contract role, was messaged by Vikas Reddy Venkannagari, a current grad student at UMBC applying for an AI Engineer role at Cisco, seeking a referral due to their shared UMBC alumni status. Anjani politely declined due to their contract role but offered assistance in other ways. No resume was shared, and the conversation ended with Vikas thanking Anjani for the response. Anjani did not agree to provide a referral but was open to other forms of assistance.',
#   'company': 'Cisco'},
#  {'message_id': 'messg_220',
#   'conversation': 'Vikas Reddy Venkannagari (2024-01-11 15:08:00): Hey Anubhav Paras, \n \nI am a graduate data science student, hoping a possible referral for the role Data Science, Verification & Validation Intern, I was hooked up the zoox development of autonomous driving cars about 3 yrs ago, since then I was following zoox regularly. \n \nI am now confident that my skills align with the role, and I believe I could nab the opportunity. \n \nHere is my resume:',
#   'summary': 'I messaged Anubhav Paras, who works at Zoox, asking for a referral for the Data Science, Verification & Validation Intern role. I mentioned my background in data science and interest in autonomous driving cars. I shared my resume with Anubhav. As of now, there has been no response or follow-up action from Anubhav.',
#   'company': 'Zoox'},
#  {'message_id': 'messg_226',
#   'conversation': 'Vikas Reddy Venkannagari (2023-10-27 10:56:00): I came across your profile which says you recruit for companies, specifically in AI and Data science roles.\n\nI am in my to first semester of masters, actively looking for internship positions, your help in this matter would be really helpful',
#   'summary': 'I messaged Vikas Reddy Venkannagari, who recruits for companies in AI and Data Science roles, expressing my interest in finding an internship during my first semester of masters. I asked for their help in this matter. They responded positively, asking for my resume and any project or portfolio work I had. I shared my resume and projects with them, and we are currently in the process of discussing potential internship opportunities.',
#   'company': 'None'},
#  {'message_id': 'messg_22',
#   'conversation': 'Vikas Reddy Venkannagari (2025-04-18 15:03:00): Hey Vaishnavi, Im Vikas, a current grad student at UMBC, applying for Software Engineer role at Salesforce. Id love your takewould you be open to a referral? I bring over 1.5 years of relevant experience and am happy to share my resume. Thanks!\nVaishnavi Amirapu (2025-04-24 18:31:00): Hello Vikas,\nSure. \n\nPlease send the following details at vaishnavi.amirapu@gmail.com \n\nFirst Name\nLast Name\nPhone Number \nEmail\nResume\nVikas Reddy Venkannagari (2025-04-25 10:37:00): thanks Vaishnavi for the quick reply; I will send them over\nVikas Reddy Venkannagari (2025-05-01 21:53:00): Hey Vaishnavi, unfortunately the above job was cancelled, can I please get a referral for another role, with job id : JR293924, Thanks\nVaishnavi Amirapu (2025-05-01 21:56:00): Sure I can look into it.\nCould you share the job role link on the same mail chain too. \nVikas Reddy Venkannagari (2025-05-01 21:56:00): sure, thanks',
#   'summary': 'I messaged Vaishnavi Amirapu, a contact at Salesforce, seeking a referral for a Software Engineer role. Vaishnavi agreed to provide a referral and requested my details and resume via email. I shared the required information promptly. Later, I asked for a referral for another role, which Vaishnavi agreed to consider and requested the job role link. The conversation is ongoing, with potential for a referral for the second role.',
#   'company': 'Salesforce'},
#  {'message_id': 'messg_141',
#   'conversation': 'Vikas Reddy Venkannagari (2025-02-26 14:15:00): Hi Kapil, Im interested in applying for an SDE role at Amazon [job id: 2850418] and would love a referral if possible. Let me know if youd be open to ithappy to share my resume. Thanks!',
#   'summary': 'I messaged Kapil, who works at Amazon, expressing interest in applying for an SDE role and requesting a referral. I offered to share my resume and thanked him for considering it. Kapil responded positively and requested my resume for review. I shared my resume with him, and the current status is awaiting his review and potential referral.',
#   'company': 'Amazon'},
#  {'message_id': 'messg_151',
#   'conversation': 'Vikas Reddy Venkannagari (2024-12-27 14:13:00): Hey Tyler Jones \n \nI took a brief detour to earn a masters in Data Science, and along the way, Ive gained some serious AI superpowers. Now that Im back, Im ready to put those skills to work and be an even better fit for EPAM than before.\n \nLets connectIm excited to see how I can contribute to the team!\n \nBest regards,\nVikas',
#   'summary': 'I messaged Tyler Jones at EPAM expressing my interest in contributing to the team after earning a masters in Data Science and gaining AI skills. I requested to connect to discuss potential opportunities. Tyler has not responded yet, so there are no follow-up actions or sharing of resume/portfolio. The current status is awaiting a response from Tyler.',
#   'company': 'EPAM Systems'},
#  {'message_id': 'messg_209',
#   'conversation': "Vikas Reddy Venkannagari (2024-04-03 10:25:00): Hello Jeffrey Perkins, \n \nI am currently enrolled as Masters Student in Data science, from University of Maryland, Baltimore County. I am looking for internship opportunities, specifically interested in the role Machine Learning Intern ('24). Can you please help me out ?\n \nThanks and regards, \nVikas Reddy",
#   'summary': 'I messaged Jeffrey Perkins at an unspecified company asking for help finding a Machine Learning Internship for 2024. I am a Masters student in Data Science at the University of Maryland, Baltimore County. Jeffrey Perkins has not responded yet, so no follow-up actions have been taken. No resume, project, or portfolio was shared in the initial message. The outcome is pending as there has been no response yet.',
#   'company': 'None'},
#  {'message_id': 'messg_123',
#   'conversation': "Vikas Reddy Venkannagari (2025-03-03 14:08:00): Hey Manas Goutham, I'm really interested in working at Capital One and l'd love to apply. I have 1.5+ years of experience in Data Analytics, and I think l'd be a great fit. Would you be open to referring me?\nVikas Reddy Venkannagari (2025-03-04 11:47:00): Hi Manas,\n \nThanks for accepting my request! Just following up on my message about the Senior Data Scientist role [job id: R209511]would you be open to referring me? Let me know if I should follow any process. Appreciate your time!\n \nI am also attaching my resume for your reference \n \nBest, Vikas",
#   'summary': 'I messaged Manas Goutham at Capital One expressing my interest in a Senior Data Scientist role and requesting a referral. I followed up the next day, attaching my resume for reference. Manas has not responded yet, so the current status is awaiting a response.',
#   'company': 'Capital One'},
#  {'message_id': 'messg_166',
#   'conversation': 'Vikas Reddy Venkannagari (2024-11-21 11:10:00): Dear Sara Marschall, \n \nI hope this message finds you well. I am reaching out to inquire about spring internship opportunities and potential full-time roles at IntelliGenesis LLC. I am inspired by IntelliGenesis dedication to delivering tailored, secure, and efficient AI solutions for critical data and intelligence needs in a mission-focused environment. \n \nWith experience in big data analytics and developing AI-driven models, I am confident my skills in Python, SQL, and machine learning frameworks can contribute to IntelliGenesis mission. My expertise in handling complex data pipelines and ensuring secure data processing aligns with your commitment to providing cutting-edge, customized solutions. \n \nI have attached my resume for your review and would welcome the opportunity to discuss how I can add value to your team. \n \nBest regards, \nVikas Reddy \nwh22215@umbc.edu \n(443)-992-2554',
#   'summary': "Summary:\n- You messaged Sara Marschall at IntelliGenesis LLC inquiring about spring internship opportunities and full-time roles.\n- Your intent was to express interest in contributing to IntelliGenesis' mission with your skills in big data analytics and AI-driven models.\n- You attached your resume for review and expressed interest in discussing how you can add value to the team.\n- No response or follow-up actions were mentioned in the conversation.\n- Current status: Pending response from Sara Marschall.",
#   'company': 'IntelliGenesis LLC'},
#  {'message_id': 'messg_24',
#   'conversation': 'Vikas Reddy Venkannagari (2025-04-30 22:28:00): Hey Prasad, Im Vikas, a current grad student at UMBC, applying for Algorithm Engineer role at KLA. Id love your takewould you be open to a referral? I bring over 1.5 years of relevant experience and am happy to share my resume. Thanks!\nPrasad Reddy (2025-04-30 22:33:00): Hi vikas . I am relatively new here and work with and mainly work on HPC hardware. I am sorry I dont know anyone in algorithm division. \nPrasad Reddy (2025-04-30 22:33:00): But, KLA is hiring a lot of people these days and you might definitely get an invite for interview. \nVikas Reddy Venkannagari (2025-05-01 20:25:00): Thanks Prasad for your reply, I will constantly look into the career page \nPrasad Reddy (2025-05-01 21:01:00):',
#   'summary': "Vikas messaged Prasad, a colleague at UMBC, seeking a referral for an Algorithm Engineer role at KLA. Prasad mentioned his unfamiliarity with the algorithm division but noted KLA's active hiring status, suggesting Vikas might still receive an interview invitation. Vikas thanked Prasad for the response and planned to monitor the career page for opportunities, indicating a positive and helpful exchange despite the lack of a direct referral. No resume or portfolio was shared, and the current status is Vikas monitoring KLA's career page for potential openings.",
#   'company': 'KLA'},
#  {'message_id': 'messg_187',
#   'conversation': 'Swapnil Joijode (2024-09-01 06:02:00): Wishing you a very happy birthday!',
#   'summary': 'I messaged Swapnil Joijode to wish them a happy birthday. There was no specific intent beyond sending birthday wishes. Swapnil responded with a thank you. No resume, project, or portfolio was shared. The conversation was brief and ended after the birthday wishes were exchanged.',
#   'company': 'Vision Group Retail'},
#  {'message_id': 'messg_198',
#   'conversation': 'Vikas Reddy Venkannagari (2024-04-10 20:03:00): Hi, \n \nI am currently enrolled in MS program (Data science) at University of Maryland, Baltimore County, I came across a summer 2024 Machine learning intern role with job id : 1809. I strongly believe that I will be a great addition to your organization.\n \nWould you be down to chat about this role ?\n \nThe job id from my connect message was incorrect, did not mean to spam you, sorry !',
#   'summary': 'I messaged Vikas Reddy Venkannagari from an unknown company inquiring about a summer 2024 Machine Learning intern role with the incorrect job ID. My intent was to discuss my potential fit for the role. Vikas responded, acknowledging the mistake in the job ID and apologized for any confusion. No resume, project, or portfolio was shared in the conversation. The outcome is unclear, but Vikas seemed open to further discussion.',
#   'company': 'NASA'},
#  {'message_id': 'messg_184',
#   'conversation': 'Vikas Reddy Venkannagari (2024-09-22 13:17:00): Hello Mihin,\n\nI am a Data science graduate student from university of Maryland, Baltimore county. I am currently looking for internship opportunities, are there any positions open in your team, and can you please help me out ?\n\nThanks and regrads, \nVikas Reddy',
#   'summary': 'You messaged Mihin, who works at an unspecified company, seeking internship opportunities in their team as a Data Science graduate student from the University of Maryland, Baltimore County. You requested their assistance in finding open positions. Mihin responded positively and requested more information about your background or resume to potentially help you out. No resume or portfolio was shared in the initial conversation, but there is potential for further communication or assistance in the internship search process.',
#   'company': 'Tinder'},
#  {'message_id': 'messg_117',
#   'conversation': 'Vikas Reddy Venkannagari (2024-04-04 00:16:00): I am your roomate\nMaddipati Venkata Akarsh (2024-04-04 00:17:00): Fu*k you bitch\nVikas Reddy Venkannagari (2025-03-22 14:45:00): This is a message',
#   'summary': 'Summary:\n- You messaged Maddipati Venkata Akarsh, who is your roommate.\n- The intent of the conversation is unclear due to the negative response received.\n- Maddipati Venkata Akarsh responded with an offensive message.\n- No resume, project, or portfolio was shared.\n- The outcome is negative, with an inappropriate response from Maddipati Venkata Akarsh.',
#   'company': 'Agile Care Enterprises, LLC'},
#  {'message_id': 'messg_196',
#   'conversation': 'Anand Y (2024-06-22 15:37:00): Congrats bro\nVikas Reddy Venkannagari (2024-06-23 17:14:00): deniki ?\nAnand Y (2024-06-23 17:15:00): RA ki\nAnand Y (2024-06-23 17:15:00): Ponle Mali Dunkin ki vele panundadu\nVikas Reddy Venkannagari (2024-06-23 17:21:00): 10 hrs echadu\nAnand Y (2024-06-23 17:21:00): oh, fall ki penchuko, fee kuda waive off aiidi\nVikas Reddy Venkannagari (2024-06-23 17:23:00): Ledu department vere kada, no additional benefits, just pay of ra ante \nAnand Y (2024-06-23 17:23:00): ohh, em kadle nerchuko idi use cheskoni vere opportnities try chei\nall the best\nVikas Reddy Venkannagari (2024-06-23 17:24:00): Nee job hunt ela undi marri \nAnand Y (2024-06-23 18:07:00): As usual\nAnand Y (2024-06-23 18:07:00): Nothing special',
#   'summary': "Anand Y messaged Vikas Reddy Venkannagari to congratulate him on something related to RA. Vikas mentioned a situation where someone had to work for 10 hours and Anand advised him to negotiate for additional benefits. Vikas explained the lack of additional benefits in his department. Anand encouraged Vikas to use this experience to explore other opportunities. No specific intent for a referral or job introduction was mentioned, and no resume or portfolio was shared. The conversation ended with general well wishes for Vikas's job hunt.",
#   'company': 'None'},
#  {'message_id': 'messg_16',
#   'conversation': 'Vikas Reddy Venkannagari (2025-05-05 09:54:00): Hey Mattie, Im Vikas, a current grad student at UMBC, applying for Data Scientist role at Itron. Id love your takewould you be open to a referral? I bring over 1.5 years of relevant experience and am happy to share my resume. Thanks!',
#   'summary': 'You messaged Mattie, who works at Itron, asking for a referral for a Data Scientist role. You mentioned your relevant experience and offered to share your resume. Mattie has not responded yet, so the outcome is pending.',
#   'company': 'Itron'},
#  {'message_id': 'messg_32',
#   'conversation': "Vikas Reddy Venkannagari (2025-04-27 06:01:00): Hey Tarun, Im Vikas, a current grad student at UMBC, applying for Data Scientist role at Medline Industries. Id love your takewould you be open to a referral? I bring over 1.5 years of relevant experience and am happy to share my resume. Thanks!\nTarun Khurana (2025-04-27 06:02:00): Hi Vikas\nPlease share the position details from the medline website along with your resume and i will see what i can do\nVikas Reddy Venkannagari (2025-04-28 09:18:00): Hey Tharun, thank you for accepting my referral, and offering me a referral\nVikas Reddy Venkannagari (2025-04-28 09:19:00): The role I am interested is Developer Analyst, with job id: R250705, below attached is my resume and LOR from my prof\nTarun Khurana (2025-04-28 09:24:00): I'll get back to you\nTarun Khurana (2025-04-28 13:11:00): I have uploaded your information internally. Please go ahead and apply using my email in the referred by section\n\nEmail:tkhurana@medline.com\nVikas Reddy Venkannagari (2025-04-28 13:12:00): Got it, thanks again !!\nTarun Khurana (2025-04-28 13:12:00): No problem",
#   'summary': 'I messaged Tarun Khurana, a contact at Medline Industries, seeking a referral for a Data Scientist role. Tarun requested the position details and my resume, to which I promptly provided. Tarun accepted my referral, uploaded my information internally, and instructed me to apply using his email in the referral section. I shared my resume and a letter of recommendation from my professor. Tarun agreed to help and guided me through the application process, indicating a positive outcome so far.',
#   'company': 'Medline Industries'},
#  {'message_id': 'messg_7',
#   'conversation': 'Vikas Reddy Venkannagari (2025-05-06 18:53:00): Hey Elton, Im Vikas, a current grad student at UMBC, applying for Software Engineer in Test role at Apple. Id love your takewould you be open to a referral? I bring over 1.5 years of relevant experience and am happy to share my resume. Thanks!',
#   'summary': 'I messaged Elton, who works at Apple, asking for a referral for a Software Engineer in Test role. I mentioned my relevant experience and offered to share my resume. Elton responded positively and asked me to send over my resume for him to review. I shared my resume with him, and we are currently waiting for his feedback or next steps.',
#   'company': 'Apple'},
#  {'message_id': 'messg_194',
#   'conversation': 'Phil Henry (2024-07-10 08:39:00): Hi Vikas Reddy, thanks for the connect, I am a Linux Admin, but really I am a full time funstigator :) and I wish you the best, feel free to enjoy my LinkedIn page, there will be plenty of shenanigans on there in the months to come.\nVikas Reddy Venkannagari (2024-07-10 12:01:00): \nPhil Henry (2024-07-10 12:58:00): Can you my most recent post a like? It would mean a lot \nVikas Reddy Venkannagari (2024-07-12 14:57:00): Done\nPhil Henry (2024-07-12 15:43:00): Thanks bud!!\nVikas Reddy Venkannagari (2024-07-12 17:00:00):',
#   'summary': 'I messaged Vikas Reddy Venkannagari, who is a Linux Admin, to ask for a like on my recent post. Vikas responded positively and liked my post. No resume, project, or portfolio was shared during the conversation. The outcome was positive, with Vikas agreeing to like my post.',
#   'company': 'Two Six Technologies'},
#  {'message_id': 'messg_222',
#   'conversation': "Vikas Reddy Venkannagari (2024-01-10 16:34:00): Hey David, \n \nI am a Data Science graduate student from University of Maryland, Baltimore county. I am reaching out for a possible shortlist and interview for the position of Data Science, Verification & Validation intern, working at zoox for enhancing autonomous navigation had been my dream for about 3 years now, I was hooked up with zoox right from when I was a sophomore, and had been constantly following zoox's news. \n \nI am attaching my resume, for your reference. I really appreciate your time for reading this message, and hoping an interview to proove myself soon. \n \nThank you",
#   'summary': 'I messaged David at Zoox expressing my interest in the Data Science, Verification & Validation intern position, sharing my resume for reference. I mentioned my long-standing dream of working at Zoox and my enthusiasm for autonomous navigation. I am hoping for a shortlist and interview opportunity to showcase my skills. David has not responded yet, so the current status is pending.',
#   'company': 'None'},
#  {'message_id': 'messg_96',
#   'conversation': 'Vikas Reddy Venkannagari (2025-04-14 09:13:00): Hey Murali, Im Vikas, a current grad student at UMBC, applying for Data Analyst role at BlackRock. Id love your takewould you be open to a referral? I bring over 1.5 years of relevant experience and am happy to share my resume. Thanks!',
#   'summary': 'I messaged Murali, who works at BlackRock, asking for a referral for a Data Analyst role. I mentioned my relevant experience and offered to share my resume. Murali responded positively and requested me to send my resume for further consideration. I shared my resume with Murali, and the current status is awaiting their response after reviewing it.',
#   'company': 'BlackRock'},
#  {'message_id': 'messg_101',
#   'conversation': 'Vikas Reddy Venkannagari (2025-04-10 18:55:00): Hi Anil, I hope youre doing well! My uncle, Venu Gopal, has spoken highly of you and your journey at Berkadia, which encouraged me to reach out. Im currently working as a Machine Learning Researcher, developing predictive models and innovative data solutions, and Im really excited about the opportunity to join Berkadia as a Senior Data Warehouse Analyst.\n \nI believe my background aligns well with the roles requirements, and Id be grateful for any advice or a referral that could help me get my foot in the door. Ive attached my resume for more details about my experience, and I appreciate your time in considering my request. Looking forward to connecting soon!\n \nBest regards,\nVikas',
#   'summary': 'Summary:\n- You messaged Anil, who works at Berkadia.\n- Your intent was to ask for advice, a referral, or help getting a foot in the door for a Senior Data Warehouse Analyst position at Berkadia.\n- Anil responded positively, expressing gratitude for your interest and mentioning he would review your resume.\n- You shared your resume for more details about your experience.\n- The current status is that Anil has shown interest and may potentially help with your application.',
#   'company': 'Berkadia'},
#  {'message_id': 'messg_116',
#   'conversation': 'Vikas Reddy Venkannagari (2025-03-22 17:57:00): Hey Tolu,\n\nIm Vikas, a current grad student at UMBC, and Im applying for a Data Scientist role at Meta. As a fellow UMBC alum, Id love to get your takewould you be open to a referral? Happy to share my resume. Thanks!',
#   'summary': 'I messaged Tolu, who works at Meta, asking for a referral for a Data Scientist role as a UMBC alum. I offered to share my resume and expressed my interest in their input. Tolu responded positively, agreeing to provide a referral and requested my resume for further review. The outcome is favorable as Tolu agreed to assist with the referral process.',
#   'company': 'Meta'},
#  {'message_id': 'messg_148',
#   'conversation': "Vikas Reddy Venkannagari (2025-02-24 16:31:00): Hi Prachi,\n\n I wanted to connect because I'm interested in the Machine Learning Scientist Intern role at your company and would appreciate any help to let me get in touch with the right contact.\n\n Thank you! Vikas Reddy.",
#   'summary': 'Summary:\n- You messaged Prachi regarding the Machine Learning Scientist Intern role at her company.\n- Your intent was to seek help connecting with the right contact for this role.\n- Prachi responded positively and offered to connect you with the relevant contact.\n- No resume, project, or portfolio was shared in the conversation.\n- The outcome is that Prachi agreed to help facilitate your connection with the right contact for the internship role.',
#   'company': 'None'},
#  {'message_id': 'messg_218',
#   'conversation': 'Vikas Reddy Venkannagari (2024-03-15 00:13:00): Hey Saurav,\n \nI am data science graduate student from UMBC. I am looking for internship opportunity this summer. I am currently volunteering as a research assistant at one of the research labs at UMBC, which researches in developing a deep learning model to effectively use EEG signals and facial features to detect emotions of humans. \n \nApart from that, I have worked as Software engineer in test at Epam systems, and as a data analyst at Indicwiki. I bring a diverse skill-set as an intern. \n \nI am attaching my resume for your reference, and I hope I get a chance to prove my authenticity through an interview.(Edited)',
#   'summary': 'I messaged Saurav expressing my interest in an internship opportunity for the summer as a data science graduate student from UMBC. I highlighted my experience as a research assistant and my diverse skill-set from previous roles. I attached my resume for reference and expressed hope for an interview to prove my authenticity. Saurav has not responded yet, so the current status is awaiting a reply.',
#   'company': 'None'},
#  {'message_id': 'messg_128',
#   'conversation': "Vikas Reddy Venkannagari (2025-02-27 18:25:00): Hey Shashi Varun, \nI'm Vikas, and am interested in applying for a Machine learning role at Microsoft [job id: 1805225] and would love a referral if possible. Let me know if youd be open to ithappy to share my resume. Thanks!\nShashi Varun Kalimera (2025-02-27 18:25:00): Hi, Vikas Reddy\nShashi Varun Kalimera (2025-02-27 18:25:00): Sure send me your resume \nShashi Varun Kalimera (2025-02-27 18:25:00): i can refer you to\nShashi Varun Kalimera (2025-02-27 18:25:00): the job id\nVikas Reddy Venkannagari (2025-02-27 18:26:00): here is my resume\nVikas Reddy Venkannagari (2025-02-27 18:26:00): with job id: 1805225; thanks for the referral, I appreciate it\nShashi Varun Kalimera (2025-02-27 18:27:00): give me some time will refer you within an hour \nVikas Reddy Venkannagari (2025-02-27 18:27:00): Sure, thanks\nVikas Reddy Venkannagari (2025-02-27 21:48:00): Shashi, thanks for the referral \nShashi Varun Kalimera (2025-02-27 21:51:00): You're welcome",
#   'summary': 'I messaged Shashi Varun Kalimera at Microsoft requesting a referral for a Machine Learning role with job ID 1805225. Shashi agreed to refer me and asked for my resume, which I promptly shared. Shashi confirmed they would refer me within an hour. After the referral was made, I thanked Shashi for their assistance, and they acknowledged my gratitude. The outcome was positive, with Shashi providing the referral as requested.',
#   'company': 'Microsoft'},
#  {'message_id': 'messg_2',
#   'conversation': 'Vikas Reddy Venkannagari (2024-04-05 23:31:00): Hi, \n\nI am currently enrolled in MS program (Data science) at University of Maryland, Baltimore County, and looking for summer 2024 internship opportunities, Is there any position available in your team? Can you help me out here. \n\nThanks and regards,\nVikas Reddy\nSameer Kibey (2024-04-06 13:54:00): Hi Vikas, my team is not hiring at the moment. But I will keep an eye on any opportunities. Suggest you to add your resume when you contact people, and briefly mention key competencies/core skills. Thus they can see what areas you will be a good fit in. \nVikas Reddy Venkannagari (2024-04-06 15:25:00): hey sameer, \n \nI am currently volunteering at a research lab in UMBC. Where we developing a transformer based model to predict the emotions by fusing EEG signal data and facial features, targeted publishing date is less than 2 months. Coming to my interests I am interested in computer vision and nlp based tasks. I am attaching my resume for your reference.(Edited)\nVikas Reddy Venkannagari (2024-04-09 23:54:00): Hey Sameer, \n \nI found an internship opportunity which I believe is a perfect fit for my background. The job is : JR026142, role of "Foundational AI Research Intern". Can you please refer me to this position. \n \nI am attaching my resume for your reference,\nSameer Kibey (2024-06-02 17:12:00): Hello Vikas, I missed responding to your message. My apologies. Are you still looking for summer internship role? I can forward your resume to the hiring manager for JR026142. However, on your resume the LinkedIn link is not valid. Suggest you to correct that. Also add a tag line at the top of the resume, that helps the reader understand what kind of role you are looking for. Something like - "Experienced graduate student looking for an internship in AI/ML/Deep Learning <or add other areas here> for Summer 2024".\nVikas Reddy Venkannagari (2024-06-02 17:12:00): Sure Sameer, I will make the changes.\nVikas Reddy Venkannagari (2024-07-13 15:56:00): Hey Sameer, I have made suitable changes and also updated my resume with my latest projects. \n \nI believe the above position is no longer open, can you please refer to the role Multimodal AI Research Intern, Job ID JR0266069. (fall 2024 internship)\n \nI would also love some comments to improve on my resume.\nSameer Kibey (2024-07-13 21:56:00): I will submit referral for the internship position.. resume looks fine to me. \nVikas Reddy Venkannagari (2024-07-13 21:57:00): Thank you very much\nSameer Kibey (2024-07-16 20:37:00): I submitted the referral, but note that the position lists minimum requirement as PhD candidate. I am not sure how flexible they would be to consider MS candidates. Anyway, all the best!\nVikas Reddy Venkannagari (2024-07-16 20:38:00): Yeah, and I saw there were no other fall 2024 internship opportunities\nVikas Reddy Venkannagari (2024-07-16 20:38:00): Thanks again, for the referral. \nVikas Reddy Venkannagari (2025-04-14 10:24:00): Hi Sameer, hope you\'re doing well.\nThanks again for the earlier referral.\n\nWould it be a ridiculous idea to ask if you or your team are hiring for other data/software roles?\nSameer Kibey (2025-05-09 12:18:00): Hello Vikas, hiring is slow at Intel at the moment. My team is not hiring for full time roles. I can send your resume to my contacts at Nvidia and Amazon that work in AI. Send me your latest resume.\nVikas Reddy Venkannagari (2025-05-09 12:18:00): Hi Sameer,\n\nThanks for your kind reply! Im working on an exciting agentic AI project that will make a great addition to my resume. It should be finalized this weekend, and Ill send my resume over in 2 days.\nSameer Kibey (2025-05-09 12:18:00): ok sounds good.',
#   'summary': "Vikas Reddy messaged Sameer Kibey inquiring about summer 2024 internship opportunities. Sameer mentioned no current openings but advised Vikas to add his resume and key skills when contacting people. Vikas shared his resume and later asked for a referral for a specific internship role, to which Sameer agreed to forward his resume with some resume improvement suggestions. Vikas later updated his resume and requested a referral for another internship role, which Sameer submitted, noting the minimum requirement as a PhD candidate. Vikas thanked Sameer for the referral and later inquired about other data/software roles, to which Sameer mentioned slow hiring at Intel but offered to send Vikas' resume to contacts at Nvidia and Amazon. Vikas planned to send his updated resume after finalizing an agentic AI project.",
#   'company': 'Intel'},
#  {'message_id': 'messg_217',
#   'conversation': 'Vikas Reddy Venkannagari (2024-03-15 00:17:00): Hey Issac,\n \nI am data science graduate student from UMBC. I am looking for internship opportunity this summer. I am currently volunteering as a research assistant at one of the research labs at UMBC, which researches in developing a deep learning model to effectively use EEG signals and facial features to detect emotions of humans. \n \nApart from that, I have worked as Software engineer in test at Epam systems, and as a data analyst at Indicwiki. Together, I am bring both research and corporate experience to your table. \n \nI am attaching my resume for your reference, and I hope to get a chance to prove my authenticity through an interview.\n \nThank you.(Edited)',
#   'summary': 'I messaged Vikas Reddy Venkannagari, a data science graduate student from UMBC, expressing my interest in an internship opportunity for the summer. I highlighted my experience as a research assistant at UMBC and my previous roles at Epam Systems and Indicwiki. I attached my resume for reference and expressed my hope for an interview to showcase my skills. Vikas has not responded yet, so the current status is awaiting a reply.',
#   'company': 'Microsoft'},
#  {'message_id': 'messg_186',
#   'conversation': 'Siddartha Kodaboina (2024-09-01 12:13:00): Wishing you a very happy birthday!\nVikas Reddy Venkannagari (2024-09-01 22:09:00): Thank you very much',
#   'summary': 'I messaged Vikas Reddy Venkannagari at an unspecified company to wish him a happy birthday. He responded with a thank you. There was no specific intent or follow-up actions mentioned in the conversation. No resume, project, or portfolio was shared. The outcome was a simple exchange of pleasantries.',
#   'company': 'AppLogic Networks'},
#  {'message_id': 'messg_21',
#   'conversation': 'Vikas Reddy Venkannagari (2025-05-02 09:14:00): Hey Rohit, Im Vikas, a current grad student at UMBC, applying for AI/ ML Engineer role at fortive. Id love your takewould you be open to a referral? I bring over 1.5 years of relevant experience and am happy to share my resume. Thanks!',
#   'summary': 'I messaged Rohit, who works at Fortive, asking for a referral for an AI/ML Engineer role. I mentioned my relevant experience and offered to share my resume. Rohit responded positively and asked me to send over my resume for him to review. I shared my resume with him, and the current status is awaiting his feedback or potential referral.',
#   'company': 'Fortive'},
#  {'message_id': 'messg_225',
#   'conversation': "Mengrui Yuan (2023-12-11 08:07:00): Hi Vikas, hello, we are a team of fence teachers, mainly from Google, Tiktok, Microsoft, the Big Four and other companies. I'm sorry, frankly speaking, this is a connection to promote job search counseling services, and I don't know if it is suitable. I am sending this to you. I dont know if it will disturb you. I actually feel a little stressed. You think, how about I briefly introduce the service content, and you decide whether we need to talk further, okay? If you are not interested, just tell me directly and we will become friends.\nVikas Reddy Venkannagari (2023-12-16 07:27:00): Please verify your profile with the organization mail, I need that to bring you.",
#   'summary': 'I messaged Vikas Reddy Venkannagari, who is associated with an organization. My intent was to promote job search counseling services offered by a team of experienced teachers from top companies. Vikas responded by requesting verification of my profile with the organization mail for further consideration. No resume, project, or portfolio was shared during the conversation. The current status is pending verification for potential collaboration.',
#   'company': 'None'},
#  {'message_id': 'messg_30',
#   'conversation': 'Vikas Reddy Venkannagari (2025-04-29 14:16:00): Hey Christian, Im Vikas, a current grad student at UMBC, applying for AI Engineer role at Cisco. As a fellow UMBC alum, Id love your takewould you be open to a referral? I bring over 1.5 years of relevant experience and am happy to share my resume. Thanks!',
#   'summary': 'I messaged Christian, who works at Cisco, asking for a referral for an AI Engineer role. I mentioned being a UMBC alum like him and shared my relevant experience. I offered to share my resume as well. Christian has not responded yet, so the outcome is pending.',
#   'company': 'Cisco'},
#  {'message_id': 'messg_155',
#   'conversation': 'Vikas Reddy Venkannagari (2024-12-27 13:59:00): Hi Julia Fetsek, \n\n I took a brief detour to earn a masters in Data Science, and along the way, Ive gained some serious AI superpowers. Now that Im back, Im ready to put those skills to work and be an even better fit for EPAM than before.\n \nLets connectIm excited to see how I can contribute to the team!\n \nBest regards,\nVikas',
#   'summary': "I messaged Julia Fetsek at EPAM on December 27, 2024, expressing my interest in contributing to the team after gaining AI skills through a master's in Data Science. I requested to connect to discuss potential opportunities. Julia has not responded yet, so there are no follow-up actions or sharing of resumes/projects. The current status is awaiting a response from Julia at EPAM.",
#   'company': 'EPAM Systems'},
#  {'message_id': 'messg_26',
#   'conversation': "Vikas Reddy Venkannagari (2025-04-30 17:40:00): Hey Ronak, Im Vikas, a current grad student at UMBC, applying for Software Engineer role at Salesforce. As a fellow UMBC alum, Id love your takewould you be open to a referral? I bring over 1.5 years of relevant experience and am happy to share my resume. Thanks!\nRonak Patil (2025-04-30 17:41:00): Hey Vikas,\nSure, please send me the job id, your resume and in 2-3 lines how this roles suits your skills\nVikas Reddy Venkannagari (2025-04-30 17:46:00): Hey Ronak, thanks for offering me a referral; One of my connection on linkedin had provided me a referral for that role. I will reach out in the future if the job role aligns with my interests.\nVikas Reddy Venkannagari (2025-04-30 17:47:00): On a related note, I was wondering if your teamor any adjacent teamsmight be hiring for a Software Engineer role?\nRonak Patil (2025-04-30 17:48:00): Ohh nice! Currently we don't have any openings in my team\nAll the best for your search!\nVikas Reddy Venkannagari (2025-04-30 17:49:00): Thanks Ronak for you support !!, please consider reaching me out if any opening comes up in your team.\nRonak Patil (2025-04-30 17:50:00): Sure, will let you know",
#   'summary': "I messaged Ronak Patil, a fellow UMBC alum, asking for a referral for a Software Engineer role at Salesforce. Ronak requested the job ID, my resume, and a brief explanation of how the role aligns with my skills. However, I mentioned that I already had a referral from another connection and would reach out if needed in the future. I inquired about potential openings in Ronak's team, but he mentioned they currently have no openings. Ronak wished me luck in my search and agreed to inform me if any openings arise in the future.",
#   'company': 'Salesforce'},
#  {'message_id': 'messg_162',
#   'conversation': 'Vikas Reddy Venkannagari (2024-12-27 11:11:00): Hi Laura Mammen,\n\nAI isnt just the future; its the presentand I see massive potential for Rekor on roads. To ride this wave even further I can be in your team. As a deep learning enthusiast and researcher, Ive developed models that hit 97% accuracy in complex tasks like emotion recognition.\n \nImagine what we could do together at Rekor. If youre open to exploring how cutting-edge research can amplify your vision, lets connect!\n \nExcited to collaborate,\nVikas',
#   'summary': 'I messaged Laura Mammen at Rekor expressing interest in joining their team due to my expertise in AI and deep learning. I highlighted my achievements in developing accurate models for complex tasks. I proposed collaborating to amplify their vision with cutting-edge research. Laura has not responded yet, and no resume or portfolio was shared. The current status is awaiting a response from Laura regarding potential collaboration.',
#   'company': 'Rekor'},
#  {'message_id': 'messg_1',
#   'conversation': 'Vikas Reddy Venkannagari (2025-05-09 19:36:00): Hey Haixu, Im Vikas, a current grad student at UMBC, applying for Algorithm Engineer role at KLA. As a fellow UMBC alum, Id love your takewould you be open to a referral? I bring over 1.5 years of relevant experience and am happy to share my resume. Thanks!',
#   'summary': 'You messaged Haixu, a fellow UMBC alum, about applying for an Algorithm Engineer role at KLA and asked for a referral due to your relevant experience. You offered to share your resume as well. Haixu responded positively and agreed to provide a referral, requesting your resume for further review. The outcome is that Haixu agreed to help with the referral process.',
#   'company': 'KLA'},
#  {'message_id': 'messg_79',
#   'conversation': "Vikas Reddy Venkannagari (2025-04-18 17:26:00): Hey Supritha, Im Vikas, a current grad student at UMBC, applying for Software Engineer role at ServiceNow. As a fellow UMBC alum, Id love your takewould you be open to a referral? I bring over 1.5 years of relevant experience and am happy to share my resume. Thanks!\nSupritha kotla (2025-04-18 17:26:00): Hi, Vikas Reddy\nSupritha kotla (2025-04-18 17:26:00): Sure send me the job ID or url\nSupritha kotla (2025-04-18 17:26:00): I can send you a referral link and you can apply through that\nVikas Reddy Venkannagari (2025-04-18 17:30:00): https://careers.servicenow.com/jobs/744000054581185/software-engineer/\n\nIs the role that I am interested in\nVikas Reddy Venkannagari (2025-04-18 17:30:00): Thanks for the quick reply \nSupritha kotla (2025-04-18 19:01:00): https://smrtr.io/qRCR_\nVikas Reddy Venkannagari (2025-04-18 19:09:00): Thanks\nSupritha kotla (2025-04-18 20:12:00): You're welcome",
#   'summary': 'I messaged Supritha Kotla, a fellow UMBC alum, asking for a referral for a Software Engineer role at ServiceNow. Supritha agreed to provide a referral link and requested the job ID or URL. I shared the job link, and Supritha promptly responded with the referral link. I thanked her, and she replied with "You\'re welcome." I shared my resume as part of the referral process. The outcome was positive, with Supritha providing the referral link for me to apply to the position.',
#   'company': 'ServiceNow'},
#  {'message_id': 'messg_63',
#   'conversation': 'Vikas Reddy Venkannagari (2025-04-24 08:17:00): Hey Henry, Im Vikas, a current grad student at UMBC, applying for Algorithm Engineer role at KLA. Id love your takewould you be open to a referral? I bring over 1.5 years of relevant experience and am happy to share my resume. Thanks!',
#   'summary': 'You messaged Henry, who works at KLA, asking for a referral for an Algorithm Engineer role. You mentioned your relevant experience and offered to share your resume. Henry responded positively and requested you to send over your resume for him to review. The outcome is currently pending as you need to follow up with sending your resume.',
#   'company': 'KLA'},
#  {'message_id': 'messg_54',
#   'conversation': 'Vikas Reddy Venkannagari (2025-04-24 14:57:00): Hi Audrey Park,\n\nIm reaching out regarding the AI/ML Engineer role at Fortive with Job id: 5645. As a Data Science graduate student at UMBC with hands-on MLOps and deep learning experience, I believe Id be a strong fit. My current work includes deploying scalable ML pipelines and optimizing inference on embedded systems.\n\nIve worked with technologies like PyTorch, MLflow, Docker, and Kubernetes, and built solutions combining NLP, computer vision, and real-time data processing. Provations focus on innovative, responsible AI in healthcare strongly aligns with my passion and skills.\n\nIve attached my resume and a recommendation letter from my professor who oversaw my AI research. Id love the chance to connect and share how I can contribute to your team.\n\nBest regards,\nVikas Reddy',
#   'summary': 'You messaged Audrey Park regarding the AI/ML Engineer role at Fortive with Job id: 5645, highlighting your relevant experience and skills as a Data Science graduate student at UMBC. You shared your resume and a recommendation letter from your professor. Your intent was to express interest in the role and showcase your qualifications. Audrey Park has not responded yet, so the current status is awaiting a response.',
#   'company': 'Fortive'},
#  {'message_id': 'messg_70',
#   'conversation': 'Vikas Reddy Venkannagari (2025-04-21 19:23:00): Hey Gregory, Im Vikas, a current grad student at UMBC, applying for Software Engineer role at Thermo Fisher [Job ID: R-01306314]. As a fellow UMBC alum, Id love your takewould you be open to a referral? I bring over 1.5 years of relevant experience and am happy to share my resume. Thanks!',
#   'summary': 'I messaged Gregory, a Thermo Fisher employee, seeking a referral for a Software Engineer role at the company. I highlighted my experience and mentioned being a UMBC alum like him. I offered to share my resume and expressed gratitude for his help. Gregory responded positively, agreeing to refer me for the position and requested my resume for further review. The outcome is favorable as Gregory agreed to provide a referral.',
#   'company': 'Thermo Fisher Scientific'},
#  {'message_id': 'messg_75',
# ...
#   'company': 'Fortive'},
#  {'message_id': 'messg_49',
#   'conversation': 'Vikas Reddy Venkannagari (2025-04-24 21:13:00): Hey Shikhar, Im Vikas, a current grad student at UMBC, applying for Data Analyst role at Redwood trust. Id love your takewould you be open to a referral? I bring over 1.5 years of relevant experience and am happy to share my resume. Thanks!\nShikhar Singh (2025-04-24 21:14:00): Sure, you can send me a resume and Ill pass it along if I see a fit\nVikas Reddy Venkannagari (2025-04-25 10:36:00): Hey Shikar, thanks for the quick reply, I am attaching my resume, and also a recommendation letter from my prof for your reference.',
#   'summary': "I messaged Shikhar Singh from Redwood Trust, requesting a referral for a Data Analyst role as a current grad student at UMBC. Shikhar agreed to pass along my resume if he sees a fit and requested me to send it. I followed up with my resume and a recommendation letter from my professor for reference. Currently waiting for Shikhar's response after sending the documents.",
#   'company': 'Redwood Trust'},
#  {'message_id': 'messg_171',
#   'conversation': 'Vikas Reddy Venkannagari (2024-11-02 20:15:00): \nVikas Reddy Venkannagari (2024-11-06 08:36:00): This post cannot be displayed. Retry',
#   'summary': 'I messaged Vikas Reddy Venkannagari from an unknown role/company on November 2, 2024, but the message content was not displayed. I followed up on November 6, 2024, but still did not receive a response. No specific intent or request for referral, meeting, or recruiter intro was mentioned in the summary. No resume, project, or portfolio was shared, and the outcome is unclear as there was no response from Vikas Reddy Venkannagari.',
#   'company': 'None'},
#  {'message_id': 'messg_84',
#   'conversation': "Vikas Reddy Venkannagari (2025-03-25 13:14:00): Hey Parth, Im Vikas, a current grad student at UMBC, applying for Software Engineer role at Snowflake. Id love your takewould you be open to a referral? I bring over 1.5 years of relevant experience and am happy to share my resume. Thanks!.(Edited)\nParth Purani (2025-03-25 13:15:00): Nice to meet you, Vikas. I can try to refer. Please send the job id, your resume, and a short blurb explaining how you meet the reqs to Parth.purani@snowflake.com\nVikas Reddy Venkannagari (2025-03-25 13:16:00): thanks Parth for the quick response, I will share my resume to your email.\nParth Purani (2025-03-25 14:05:00): Referred\nVikas Reddy Venkannagari (2025-04-15 17:38:00): Hi Parth,  hope you're doing well.\nThanks again for the earlier referral  my resume wasnt shortlisted by the ATS for the previous role.\n\nWould it be out of line to ask if youd be open to passing my resume along to the recruiter or hiring manager? Id truly appreciate any support you could offer.\n\nThe role just opened 5 hours ago, job id :  REQ15337, and I am attaching my resume as well a recommendation letter from my professor.\nParth Purani (2025-04-15 17:41:00): Hey Vikas I can try to refer you again if you could please send those same fields to the same email address\nVikas Reddy Venkannagari (2025-04-15 17:42:00): sending right away\nParth Purani (2025-04-15 17:59:00): Referred\nVikas Reddy Venkannagari (2025-04-15 18:00:00): Thanks a lot Parth\nVikas Reddy Venkannagari (2025-04-15 18:04:00): Hey Parth, quick question, even the last time, I was not notified that I was referred ?, Do you know what are my next steps ?\nParth Purani (2025-04-15 18:05:00): Yeah they only reach out if they want to move forward\nVikas Reddy Venkannagari (2025-04-15 18:07:00): understood, thanks",
#   'summary': 'I messaged Parth Purani, a contact at Snowflake, seeking a referral for a Software Engineer role. Parth agreed to refer me and requested my resume and additional information via email. After my initial application was not shortlisted, I reached out again for a referral for a newly opened role, providing the necessary documents. Parth referred me once more, and I inquired about the notification process for referrals, to which Parth explained that they only reach out if there is further interest. The conversation ended with me thanking Parth for the assistance.',
#   'company': 'Snowflake'},
#  {'message_id': 'messg_221',
#   'conversation': 'Vikas Reddy Venkannagari (2024-01-10 16:25:00): Hey Gaurav, \n \nI am a graduate data science student, hoping a possible referral for the role Data Science, Verification & Validation Intern, I was hooked up the zoox development of autonomous driving cars about 3 yrs ago, since then I was following zoox regularly. \n \nI am now confident that my skills align with the role, and I believe I could nab the opportunity. \n \nHere is my resume:\nGaurav Patnashetty (2024-01-10 19:10:00): Thanks for reaching out. I dont refer people I dont personally know. However, Happy to answer questions. \nVikas Reddy Venkannagari (2024-01-10 21:04:00): Oh, ok.\n\nNo problem',
#   'summary': "I messaged Gaurav Patnashetty, who works at an unknown company, seeking a referral for a Data Science, Verification & Validation Intern role. I shared my resume with him to showcase my skills and interest in the position. Gaurav responded that he doesn't refer people he doesn't know personally but offered to answer any questions. The conversation ended with me acknowledging his response and expressing understanding of his stance. No further actions were taken, and Gaurav did not agree to provide a referral.",
#   'company': 'Zoox'},
#  {'message_id': 'messg_5',
#   'conversation': 'Vikas Reddy Venkannagari (2025-05-06 21:03:00): Hey Justin, Im Vikas, a current grad student at UMBC, applying for AI Solutions Engineer role at Thomson Reuters. Id love your takewould you be open to a referral? I bring over 1.5 years of relevant experience and am happy to share my resume. Thanks!',
#   'summary': 'You messaged Justin, an individual at Thomson Reuters, seeking a referral for the AI Solutions Engineer role. You mentioned your relevant experience and offered to share your resume. Justin responded positively and requested your resume for further review. The outcome is pending as Justin has shown interest in potentially referring you for the position.',
#   'company': 'Thomson Reuters'},
#  {'message_id': 'messg_41',
#   'conversation': "Umme Kulsum (2025-04-21 14:07:00): hey this is kulsum\nI am a 2nd semester MSIS graduate student and UMBC. I see that you are a grader and i have been reaching out to professor for grader positions too. \nJust wanted your resume for reference, or if you can tell me what should i include in my resume to increase my chances.\nVikas Reddy Venkannagari (2025-04-21 19:16:00): Hello Kulsum, the grader position at the Data science department depends on your coursework taken and grades achieved. \n\nI used the following template to make my resume : https://www.overleaf.com/latex/templates/jakes-resume/syzfjbzwjncs\nVikas Reddy Venkannagari (2025-04-21 19:19:00): My resume can be downloaded at vvikasreddy.github.io ; sorry for the inconvenience I'm out of town. \nUmme Kulsum (2025-04-27 12:34:00): No problem\nUmme Kulsum (2025-04-27 12:34:00): Thankyou",
#   'summary': "Umme Kulsum messaged Vikas Reddy Venkannagari, a grader at the Data Science department, seeking advice on applying for a grader position. She requested Vikas's resume for reference and tips on improving her own resume. Vikas shared a resume template link and directed Umme to his resume on his website. Umme thanked Vikas for the information, indicating a positive interaction and potential help in her job application process.",
#   'company': 'University of Maryland, Baltimore County'},
#  {'message_id': 'messg_46',
#   'conversation': 'Vikas Reddy Venkannagari (2025-04-25 16:45:00): This message has been deleted.',
#   'summary': 'Summary: A message was sent to Vikas Reddy Venkannagari on April 25, 2025, at 4:45 PM, but it has been deleted. No further details about the content of the message, response, or outcome are available.',
#   'company': 'Wells Fargo'},
#  {'message_id': 'messg_165',
#   'conversation': 'Vikas Reddy Venkannagari (2024-11-21 11:15:00): Dear Neil Dixit, \n \nI hope this message finds you well. I am reaching out to explore spring internship opportunities and potential full-time roles at Glimpse. I greatly admire Glimpses innovative approach as an AI-powered, self-service platform that transforms language, emotion, and sentiment analysis into actionable insights for marketers and creators. \n \nWith a strong background in natural language processing and sentiment analysis, I have experience developing AI solutions that analyze complex data and provide meaningful insights over time. My skills in Python, machine learning frameworks, and data visualization make me well-suited to contribute to Glimpses mission of simplifying and accelerating perception and behavior analysis. \n \nI have attached my resume for your consideration and would be delighted to discuss how my expertise aligns with Glimpses goals. \n \nBest regards, \nVikas Reddy \nwh22215@umbc.edu \n(443)-992-2554',
#   'summary': "Summary:\n- You messaged Neil Dixit at Glimpse expressing interest in spring internship opportunities and potential full-time roles due to your admiration for the company's innovative approach in AI-powered self-service platforms.\n- You highlighted your background in natural language processing and sentiment analysis, emphasizing your skills in Python, machine learning frameworks, and data visualization that align with Glimpse's mission.\n- You attached your resume for consideration and expressed eagerness to discuss further alignment of your expertise with Glimpse's goals.\n- Outcome: Pending response from Neil Dixit at Glimpse regarding potential opportunities.",
#   'company': 'Glimpse'},
#  {'message_id': 'messg_43',
#   'conversation': 'Vikas Reddy Venkannagari (2025-04-26 13:06:00): This message has been deleted.',
#   'summary': 'Summary: A message was sent to Vikas Reddy Venkannagari, but it has been deleted, so the content and intent of the message are unknown. No response or follow-up actions were mentioned in the summary. No resume, project, or portfolio was shared, and the outcome or current status of the conversation is unclear.',
#   'company': 'None'},
#  {'message_id': 'messg_174',
#   'conversation': 'Vikas Reddy Venkannagari (2024-11-02 21:28:00): Hi Hi Shantanu Rangnath,\n\nI hope youre doing well. Im reaching out to request a referral for the Software Engineer Intern position. I am currently a graduate student in Data Science at the University of Maryland, Baltimore County, where I also work as a Research Assistant focused on using deep learning to predict signal behavior.\n\nIve attached my resume for your reference. Thank you very much for considering my request.',
#   'summary': 'You messaged Shantanu Rangnath requesting a referral for the Software Engineer Intern position. You mentioned your background as a graduate student in Data Science and Research Assistant at the University of Maryland, Baltimore County. You attached your resume for their reference. As of now, there has been no response or follow-up action mentioned in the conversation.',
#   'company': 'None'},
#  {'message_id': 'messg_3',
#   'conversation': 'Vikas Reddy Venkannagari (2025-05-08 01:08:00): Hey Bhavya, Im Vikas, a current grad student at UMBC, applying for Software Engineer in Test role at Apple. Id love your takewould you be open to a referral? I bring over 1.5 years of relevant experience and am happy to share my resume. Thanks!\nBhavya Shah (2025-05-08 01:08:00): Sure. Can you send me the job role and resume at shahbhavyan12@gmail.com\nVikas Reddy Venkannagari (2025-05-09 13:12:00): Hey Bhavya Shah, I have sent you an email.\nVikas Reddy Venkannagari (2025-05-09 13:12:00): I also noticed that Apple has just opened machine-learning roles for recent graduates. Im finishing an exciting LLM-based project this weekwould you be willing to refer me for one of those positions as well?',
#   'summary': 'I messaged Bhavya Shah, a contact at Apple, seeking a referral for a Software Engineer in Test role. Bhavya agreed and requested my resume via email. After sending the resume, I inquired about machine-learning roles for recent graduates at Apple, mentioning my relevant project. Bhavya expressed willingness to refer me for those positions as well. No further actions were mentioned, but the conversation ended positively with potential referrals for multiple roles at Apple.',
#   'company': 'Apple'},
#  {'message_id': 'messg_0',
#   'conversation': "Vikas Reddy Venkannagari (2024-11-04 20:28:00): Hi Namruth Goud,\n\nIt's been some time since we connected. We both studied at University of Maryland Baltimore County. How have you been?\nNamruth Thimmapuram (2024-11-10 23:25:00): Hi, Vikas Reddy\nNamruth Thimmapuram (2024-11-10 23:25:00): I'm good\nNamruth Thimmapuram (2024-11-10 23:25:00): How about you?\nVikas Reddy Venkannagari (2024-11-11 20:37:00): I'm good, too\nVikas Reddy Venkannagari (2024-11-15 22:42:00): profile pic bagunda ?\nVikas Reddy Venkannagari (2024-11-15 22:56:00): baane extralu\nNamruth Thimmapuram (2024-11-16 08:37:00): Yeah\nVikas Reddy Venkannagari (2025-01-09 19:50:00): \nVikas Reddy Venkannagari (2025-01-14 15:48:00): \nVikas Reddy Venkannagari (2025-01-14 15:49:00): \nVikas Reddy Venkannagari (2025-01-14 15:49:00): Rey, idi chaduvu, clarity vastadi\nNamruth Thimmapuram (2025-01-28 13:40:00): endi ra adantha\nVikas Reddy Venkannagari (2025-05-09 19:48:00): Hi \nNamruth Thimmapuram (2025-05-09 19:48:00): How are you?\nVikas Reddy Venkannagari (2025-05-09 19:48:00): What are you doing \nNamruth Thimmapuram (2025-05-09 19:48:00): Working\nNamruth Thimmapuram (2025-05-09 19:48:00): And you?\nVikas Reddy Venkannagari (2025-05-09 19:48:00): Let's gor for a walk ?\nVikas Reddy Venkannagari (2025-05-09 19:48:00): Now ?\nVikas Reddy Venkannagari (2025-05-09 19:48:00): Thank you\nNamruth Thimmapuram (2025-05-09 19:48:00): Right now\nVikas Reddy Venkannagari (2025-05-09 19:48:00): Yeah\nNamruth Thimmapuram (2025-05-09 19:48:00): Goodbye",
#   'summary': 'I messaged Namruth Thimmapuram, a connection from the University of Maryland Baltimore County, to catch up. We exchanged pleasantries, and the conversation remained casual with comments on profile pictures. There was no specific intent mentioned in the conversation, and no resume, project, or portfolio was shared. The conversation ended with a suggestion to go for a walk, which Namruth agreed to, indicating a friendly interaction.',
#   'company': 'University of Maryland Baltimore County'},
#  {'message_id': 'messg_159',
#   'conversation': 'Vikas Reddy Venkannagari (2024-12-27 11:37:00): Hey Akash Raju, \n \n Glimpess vision inspires me, and Id love to be part of your journey. Heres the equation I bring to the table:\n \nGlimpse + my expertise in AI and end-to-end systems = breakthroughs waiting to happen.\n \nIm actively seeking internships or full-time opportunities where I can contribute by:\n \n - Building robust, end-to-end AI solutions.\n - Automating workflows for efficiency.\n - Leveraging data to drive strategic decisions.\n \nLets connect to discuss how I can add value to Glimpses mission!\n \nlukewarm regards,\nVikas',
#   'summary': 'Summary:\n- You messaged Akash Raju from Glimpess.\n- Your intent was to express interest in joining Glimpess and contributing your expertise in AI and end-to-end systems.\n- Akash Raju responded positively to your message.\n- No resume, project, or portfolio was shared in the conversation.\n- The outcome is that Akash Raju may be open to discussing potential opportunities for you to contribute to Glimpess.',
#   'company': 'Glimpse'}]

# %%
# Add new columns to the linkedin_summary table
cursor.execute("""
ALTER TABLE linkedin_summary
ADD COLUMN IF NOT EXISTS chat_summary TEXT,
ADD COLUMN IF NOT EXISTS company TEXT;
""")

# Commit the changes
connection.commit()

print("Columns 'chat_summary' and 'company' added successfully.")
# Out:
# Columns 'chat_summary' and 'company' added successfully.

# %%
# Update the linkedin_summary table with summary and company for each message_id
update_sql = """
UPDATE linkedin_summary
SET chat_summary = %s, company = %s
WHERE message_id = %s;
"""
 
for summary_record in summaries:
    try:
        cursor.execute(update_sql, (summary_record["summary"], summary_record["company"], summary_record["message_id"]))
    except Exception as e:
        print(f"Error updating message_id {summary_record['message_id']}: {e}")

# Commit the changes
connection.commit()

print("Summary and company information updated successfully.")
# Out:
# Summary and company information updated successfully.

# %%
print(data)
# Out:
# {'company_name': 'Glimpse'}
